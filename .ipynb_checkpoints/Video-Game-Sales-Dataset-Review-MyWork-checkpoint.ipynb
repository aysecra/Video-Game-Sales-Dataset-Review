# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import graph_objects as go
from plotly import express as px
from plotly.offline import init_notebook_mode, iplot

# %%
Games = pd.read_csv("vgsales.csv")
Games.isna().any()
# Out:
# Rank            False
# Name            False
# Platform        False
# Year             True
# Genre           False
# Publisher        True
# NA_Sales        False
# EU_Sales        False
# JP_Sales        False
# Other_Sales     False
# Global_Sales    False
# dtype: bool

# %%
bool_series = pd.isnull(Games["Year"])
Games[bool_series].count()
# Out:
# Rank            271
# Name            271
# Platform        271
# Year              0
# Genre           271
# Publisher       249
# NA_Sales        271
# EU_Sales        271
# JP_Sales        271
# Other_Sales     271
# Global_Sales    271
# dtype: int64

# %%
Games[bool_series].head(50)
# Out:
#       Rank                                               Name Platform  Year  \
# 179    180                                    Madden NFL 2004      PS2   NaN
# 377    378                                   FIFA Soccer 2004      PS2   NaN
# 431    432                         LEGO Batman: The Videogame      Wii   NaN
# 470    471                         wwe Smackdown vs. Raw 2006      PS2   NaN
# 607    608                                     Space Invaders     2600   NaN
# 624    625                                          Rock Band     X360   NaN
# 649    650           Frogger's Adventures: Temple of the Frog      GBA   NaN
# 652    653        LEGO Indiana Jones: The Original Adventures      Wii   NaN
# 711    713                                     Call of Duty 3      Wii   NaN
# 782    784                                          Rock Band      Wii   NaN
# 1126  1128                            Call of Duty: Black Ops       PC   NaN
# 1133  1135                                          Rock Band      PS3   NaN
# 1303  1305                                     Triple Play 99       PS   NaN
# 1433  1435                       LEGO Harry Potter: Years 5-7      Wii   NaN
# 1498  1500                         LEGO Batman: The Videogame      PSP   NaN
# 1513  1515                                          Adventure     2600   NaN
# 1585  1587                                             Combat     2600   NaN
# 1649  1651                                NASCAR Thunder 2003      PS2   NaN
# 1697  1699                          Hitman 2: Silent Assassin       XB   NaN
# 1837  1839                                          Rock Band      PS2   NaN
# 1990  1992                        Legacy of Kain: Soul Reaver       PS   NaN
# 2019  2021                               Donkey Kong Land III       GB   NaN
# 2086  2088                       LEGO Harry Potter: Years 5-7     X360   NaN
# 2113  2115                                     Air-Sea Battle     2600   NaN
# 2114  2116                                       Suikoden III      PS2   NaN
# 2134  2136                                           Yakuza 4      PS3   NaN
# 2145  2147                       LEGO Harry Potter: Years 5-7      PS3   NaN
# 2173  2175                                   Wheel of Fortune      PS2   NaN
# 2286  2288                                       Namco Museum       XB   NaN
# 2295  2297                                      Rhythm Heaven      Wii   NaN
# 2415  2417            The Lord of the Rings: War in the North      PS3   NaN
# 2422  2424            The Lord of the Rings: War in the North     X360   NaN
# 2484  2486                                      Madden NFL 07      PSP   NaN
# 2497  2499                                 MLB SlugFest 20-03      PS2   NaN
# 2528  2530                           Shaun White Snowboarding     X360   NaN
# 2586  2588                     PES 2009: Pro Evolution Soccer      PSP   NaN
# 2776  2778                                      Madden NFL 11      Wii   NaN
# 2786  2788                                WarioWare: Twisted!      GBA   NaN
# 2838  2840                       LEGO Harry Potter: Years 5-7       DS   NaN
# 2947  2949                             Test Drive Unlimited 2     X360   NaN
# 3049  3051  The Chronicles of Narnia: The Lion, The Witch ...      GBA   NaN
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 179       0.26      0.01         0.71          5.23
# 377       2.36      0.04         0.51          3.49
# 431       1.02      0.00         0.29          3.17
# 470       1.02      0.00         0.41          3.00
# 607       0.14      0.00         0.03          2.53
# 624       0.34      0.00         0.21          2.48
# 649       0.18      0.00         0.07          2.39
# 652       0.63      0.00         0.22          2.39
# 711       0.84      0.00         0.23          2.26
# 782       0.56      0.00         0.20          2.11
# 1126      0.81      0.00         0.24          1.63
# 1133      0.41      0.00         0.22          1.62
# 1303      0.55      0.00         0.10          1.46
# 1433      0.47      0.00         0.13          1.36
# 1498      0.46      0.00         0.28          1.32
# 1513      0.08      0.00         0.01          1.30
# 1585      0.07      0.00         0.01          1.25
# 1649      0.46      0.00         0.16          1.22
# 1697      0.38      0.00         0.05          1.19
# 1837      0.06      0.00         0.35          1.11
# 1990      0.40      0.00         0.07          1.04
# 2019      0.31      0.00         0.04          1.03
# 2086      0.39      0.00         0.09          0.99
# 2113      0.06      0.00         0.01          0.98
# 2114      0.23      0.38         0.08          0.98
# 2134      0.14      0.63         0.05          0.97
# 2145      0.45      0.00         0.16          0.97
# 2173      0.36      0.00         0.12          0.95
# 2286      0.11      0.00         0.04          0.91
# 2295      0.00      0.77         0.01          0.90
# 2415      0.45      0.01         0.15          0.86
# 2422      0.26      0.00         0.08          0.86
# 2484      0.03      0.00         0.04          0.83
# 2497      0.32      0.00         0.11          0.83
# 2528      0.26      0.00         0.08          0.82
# 2586      0.33      0.26         0.17          0.80
# 2776      0.00      0.00         0.05          0.74
# 2786      0.06      0.50         0.02          0.74
# 2838      0.30      0.00         0.07          0.72
# 2947      0.32      0.00         0.07          0.69
# 3049      0.18      0.00         0.01          0.67
# 3141      0.35      0.01         0.12          0.64
# 3194      0.00      0.63         0.00          0.63
# 3217      0.13      0.00         0.06          0.63
# 3238      0.22      0.00         0.03          0.62
# 3346      0.28      0.00         0.07          0.60
# 3421      0.00      0.01         0.03          0.59
# 3468      0.22      0.00         0.07          0.58
# 3501      0.02      0.00         0.03          0.58
# 3715      0.10      0.00         0.02          0.54

# %%
bool_series = pd.isnull(Games["Publisher"])
Games[bool_series].count()
# Out:
# Rank            58
# Name            58
# Platform        58
# Year            36
# Genre           58
# Publisher        0
# NA_Sales        58
# EU_Sales        58
# JP_Sales        58
# Other_Sales     58
# Global_Sales    58
# dtype: int64

# %%
Games[bool_series]
# Out:
#         Rank                                               Name Platform  \
# 470      471                         wwe Smackdown vs. Raw 2006      PS2
# 1303    1305                                     Triple Play 99       PS
# 1662    1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222    2224                                 Bentley's Hackpack      GBA
# 3159    3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3166    3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3766    3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4145    4147                                 Sonic the Hedgehog      PS3
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# 6272    6274  The Legend of Zelda: The Minish Cap(weekly JP ...      GBA
# 6437    6439           Sonic X: Game Boy Advance Video Volume 1      GBA
# 6562    6564  Dora the Explorer: Game Boy Advance Video Volu...      GBA
# 6648    6650  Cartoon Network Collection: Game Boy Advance V...      GBA
# 6849    6851     All Grown Up!: Game Boy Advance Video Volume 1      GBA
# 7208    7210  Nicktoons Collection: Game Boy Advance Video V...      GBA
#
# 6648          0.00          0.25
# 6849          0.00          0.24
# 7208          0.00          0.22
# 7351          0.03          0.21
# 7470          0.00          0.21
# 7953          0.00          0.19
# 8330          0.00          0.17
# 8341          0.00          0.17
# 8368          0.00          0.17
# 8503          0.00          0.16
# 8770          0.00          0.15
# 8848          0.00          0.15
# 8896          0.00          0.15
# 9517          0.00          0.13
# 9749          0.00          0.12
# 10382         0.00          0.11
# 10494         0.00          0.10
# 11076         0.01          0.09
# 11526         0.00          0.08
# 12487         0.00          0.06
# 12517         0.00          0.06
# 13278         0.00          0.05
# 13672         0.00          0.04
# 13962         0.00          0.04
# 14087         0.00          0.04
# 14296         0.00          0.03
# 14311         0.00          0.03
# 14698         0.00          0.03
# 14942         0.00          0.02
# 15056         0.00          0.02
# 15261         0.00          0.02
# 15325         0.00          0.02
# 15353         0.00          0.02
# 15788         0.00          0.02
# 15915         0.00          0.02
# 16191         0.00          0.01
# 16198         0.00          0.01
# 16208         0.00          0.01
# 16229         0.00          0.01
# 16367         0.00          0.01
# 16494         0.00          0.01
# 16543         0.00          0.01
# 16553         0.00          0.01

# %%
games = Games.dropna()

# %%
years_with_nan = games.Year.unique()
nan_array = np.isnan(years_with_nan)
not_nan_array = ~ nan_array
years = years_with_nan[not_nan_array]
years.sort()
years
# Out:
# array([1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988.,
#        1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997.,
#        1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016., 2017., 2020.])

# %%
years_by_numb_of_games_values = games.Year.value_counts().keys().tolist()
years_by_numb_of_games_counts = games.Year.value_counts().tolist()
games.Year.value_counts()
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# 2012.0     655
# 2015.0     614
# 2014.0     580
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     342
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
games.Publisher
# Out:
# 0          Nintendo
# 1          Nintendo
# 2          Nintendo
# 3          Nintendo
# 4          Nintendo
#             ...
# 16593         Kemco
# 16594    Infogrames
# 16595    Activision
# 16596      7G//AMES
# 16597       Wanadoo
# Name: Publisher, Length: 16291, dtype: object

# %%
#according to game amount
tops_publisher = games.Publisher.value_counts().head(10)
px.bar(tops_publisher, title= "Top 10 Video Game Publishers According To Game Amount",
      labels={
          "value" : "Number of Games Publishing",
          "index" : "Name of the Publisher"
      })
# Out:
# <div>                            <div id="4d1f4a61-1a9b-44a6-8435-8d132f996f19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d1f4a61-1a9b-44a6-8435-8d132f996f19")) {                    Plotly.newPlot(                        "4d1f4a61-1a9b-44a6-8435-8d132f996f19",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Publisher<br>Name of the Publisher=%{x}<br>Number of Games Publishing=%{y}<extra></extra>", "legendgroup": "Publisher", "marker": {"color": "#636efa"}, "name": "Publisher", "offsetgroup": "Publisher", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Electronic Arts", "Activision", "Namco Bandai Games", "Ubisoft", "Konami Digital Entertainment", "THQ", "Nintendo", "Sony Computer Entertainment", "Sega", "Take-Two Interactive"], "xaxis": "x", "y": [1339, 966, 928, 918, 823, 712, 696, 682, 632, 412], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777777 ...

# %%
#according to global game sales
top10_sales_Publisher = []
len(games.Publisher.unique())
# Out:
# 576

# %%
#sort according to Global_Sales
publisher_sales = games.loc[:,["Name" ,"Publisher", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales",
                               "Global_Sales"]].groupby(by="Publisher").sum()
#reversed_df = df.iloc[::-1]
max_gsales_publisher = publisher_sales.sort_values(["Global_Sales"]).tail(10)
tops_publisher_gsales = max_gsales_publisher.iloc[::-1]
tops_publisher_gsales
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                        815.75    418.30    454.99        95.19
# Electronic Arts                 584.22    367.38     13.98       127.63
# Activision                      426.01    213.72      6.54        74.79
# Sony Computer Entertainment     265.22    187.55     74.10        80.40
# Ubisoft                         252.81    163.03      7.33        50.16
# Take-Two Interactive            220.47    117.95      5.83        55.20
# THQ                             208.60     94.60      5.01        32.11
# Konami Digital Entertainment     88.91     68.62     90.93        29.91
# Sega                            108.78     81.41     56.19        24.30
# Namco Bandai Games               69.38     42.61    126.84        14.64
#
#                               Global_Sales
# Publisher
# Nintendo                           1784.43
# Electronic Arts                    1093.39
# Activision                          721.41
# Sony Computer Entertainment         607.28
# Ubisoft                             473.54
# Take-Two Interactive                399.30
# THQ                                 340.44
# Konami Digital Entertainment        278.56
# Sega                                270.70
# Namco Bandai Games                  253.65

# %%
px.bar(tops_publisher_gsales["Global_Sales"], title= "Top 10 Video Game Publishers According To Global Game Sales",
      labels={
          "value" : "Number of Games Publishing",
          "index" : "Name of the Publisher"
      })
# Out:
# <div>                            <div id="99bc946a-562d-4904-bddb-7d203262e639" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99bc946a-562d-4904-bddb-7d203262e639")) {                    Plotly.newPlot(                        "99bc946a-562d-4904-bddb-7d203262e639",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Global_Sales<br>Publisher=%{x}<br>Number of Games Publishing=%{y}<extra></extra>", "legendgroup": "Global_Sales", "marker": {"color": "#636efa"}, "name": "Global_Sales", "offsetgroup": "Global_Sales", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Nintendo", "Electronic Arts", "Activision", "Sony Computer Entertainment", "Ubisoft", "Take-Two Interactive", "THQ", "Konami Digital Entertainment", "Sega", "Namco Bandai Games"], "xaxis": "x", "y": [1784.4299999999982, 1093.389999999996, 721.4099999999981, 607.2799999999988, 473.53999999999934, 399.2999999999996, 340.43999999999943, 278.559999999998, 270.69999999999925, 253.65000000000083], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"] ...

# %%
#according to japan game sales
max_jsales_publisher = publisher_sales.sort_values(["JP_Sales"]).tail(10)
tops_publisher_jsales = max_jsales_publisher.iloc[::-1]
tops_publisher_jsales
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                        815.75    418.30    454.99        95.19
# Namco Bandai Games               69.38     42.61    126.84        14.64
# Konami Digital Entertainment     88.91     68.62     90.93        29.91
# Sony Computer Entertainment     265.22    187.55     74.10        80.40
# Capcom                           78.45     39.16     67.38        14.82
# Sega                            108.78     81.41     56.19        24.30
# Square Enix                      48.59     32.57     49.79        13.84
# SquareSoft                       11.06      4.95     40.13         1.54
# Enix Corporation                  0.76      0.31     32.40         0.27
# Tecmo Koei                       14.08      7.08     29.21         3.18
#
#                               Global_Sales
# Publisher
# Nintendo                           1784.43
# Namco Bandai Games                  253.65
# Konami Digital Entertainment        278.56
# Sony Computer Entertainment         607.28
# Capcom                              199.95
# Sega                                270.70
# Square Enix                         144.73
# SquareSoft                           57.65
# Enix Corporation                     33.74
# Tecmo Koei                           53.55

# %%
px.bar(tops_publisher_jsales["JP_Sales"], title= "Top 10 Video Game Publishers According To Game Sales in Japan",
      labels={
          "value" : "Number of Games Publishing",
          "index" : "Name of the Publisher"
      })
# Out:
# <div>                            <div id="5f97b4ac-990a-49f2-a592-9f928d8855a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f97b4ac-990a-49f2-a592-9f928d8855a8")) {                    Plotly.newPlot(                        "5f97b4ac-990a-49f2-a592-9f928d8855a8",                        [{"alignmentgroup": "True", "hovertemplate": "variable=JP_Sales<br>Publisher=%{x}<br>Number of Games Publishing=%{y}<extra></extra>", "legendgroup": "JP_Sales", "marker": {"color": "#636efa"}, "name": "JP_Sales", "offsetgroup": "JP_Sales", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Nintendo", "Namco Bandai Games", "Konami Digital Entertainment", "Sony Computer Entertainment", "Capcom", "Sega", "Square Enix", "SquareSoft", "Enix Corporation", "Tecmo Koei"], "xaxis": "x", "y": [454.98999999999955, 126.84000000000007, 90.93, 74.10000000000004, 67.38000000000004, 56.19000000000002, 49.790000000000006, 40.13, 32.399999999999984, 29.210000000000004], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.444 ...

# %%
#according to europe game sales
max_esales_publisher = publisher_sales.sort_values(["EU_Sales"]).tail(10)
tops_publisher_esales = max_esales_publisher.iloc[::-1]
tops_publisher_esales
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                        815.75    418.30    454.99        95.19
# Electronic Arts                 584.22    367.38     13.98       127.63
# Activision                      426.01    213.72      6.54        74.79
# Sony Computer Entertainment     265.22    187.55     74.10        80.40
# Ubisoft                         252.81    163.03      7.33        50.16
# Take-Two Interactive            220.47    117.95      5.83        55.20
# THQ                             208.60     94.60      5.01        32.11
# Sega                            108.78     81.41     56.19        24.30
# Konami Digital Entertainment     88.91     68.62     90.93        29.91
# Microsoft Game Studios          155.35     68.61      3.26        18.56
#
#                               Global_Sales
# Publisher
# Nintendo                           1784.43
# Electronic Arts                    1093.39
# Activision                          721.41
# Sony Computer Entertainment         607.28
# Ubisoft                             473.54
# Take-Two Interactive                399.30
# THQ                                 340.44
# Sega                                270.70
# Konami Digital Entertainment        278.56
# Microsoft Game Studios              245.79

# %%
px.bar(tops_publisher_esales["EU_Sales"], title= "Top 10 Video Game Publishers According To Game Sales in Europe",
      labels={
          "value" : "Number of Games Publishing",
          "index" : "Name of the Publisher"
      })
# Out:
# <div>                            <div id="49864a37-8aff-448a-bac8-1a298947781d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49864a37-8aff-448a-bac8-1a298947781d")) {                    Plotly.newPlot(                        "49864a37-8aff-448a-bac8-1a298947781d",                        [{"alignmentgroup": "True", "hovertemplate": "variable=EU_Sales<br>Publisher=%{x}<br>Number of Games Publishing=%{y}<extra></extra>", "legendgroup": "EU_Sales", "marker": {"color": "#636efa"}, "name": "EU_Sales", "offsetgroup": "EU_Sales", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Nintendo", "Electronic Arts", "Activision", "Sony Computer Entertainment", "Ubisoft", "Take-Two Interactive", "THQ", "Sega", "Konami Digital Entertainment", "Microsoft Game Studios"], "xaxis": "x", "y": [418.3000000000002, 367.3799999999965, 213.72000000000037, 187.55000000000018, 163.0299999999997, 117.95000000000017, 94.60000000000018, 81.41000000000014, 68.6200000000002, 68.61000000000006], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.333333333 ...

# %%
#according to north america game sales
max_nsales_publisher = publisher_sales.sort_values(["NA_Sales"]).tail(10)
tops_publisher_nsales = max_nsales_publisher.iloc[::-1]
tops_publisher_nsales
# Out:
#                              NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                       815.75    418.30    454.99        95.19
# Electronic Arts                584.22    367.38     13.98       127.63
# Activision                     426.01    213.72      6.54        74.79
# Sony Computer Entertainment    265.22    187.55     74.10        80.40
# Ubisoft                        252.81    163.03      7.33        50.16
# Take-Two Interactive           220.47    117.95      5.83        55.20
# THQ                            208.60     94.60      5.01        32.11
# Microsoft Game Studios         155.35     68.61      3.26        18.56
# Sega                           108.78     81.41     56.19        24.30
# Atari                          101.23     25.80     10.70         8.73
#
#                              Global_Sales
# Publisher
# Nintendo                          1784.43
# Electronic Arts                   1093.39
# Activision                         721.41
# Sony Computer Entertainment        607.28
# Ubisoft                            473.54
# Take-Two Interactive               399.30
# THQ                                340.44
# Microsoft Game Studios             245.79
# Sega                               270.70
# Atari                              146.77

# %%
px.bar(tops_publisher_nsales["NA_Sales"], title= "Top 10 Video Game Publishers According To Game Sales in North America",
      labels={
          "value" : "Number of Games Publishing",
          "index" : "Name of the Publisher"
      })
# Out:
# <div>                            <div id="3212a677-5e73-4633-ade8-049dc8840d04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3212a677-5e73-4633-ade8-049dc8840d04")) {                    Plotly.newPlot(                        "3212a677-5e73-4633-ade8-049dc8840d04",                        [{"alignmentgroup": "True", "hovertemplate": "variable=NA_Sales<br>Publisher=%{x}<br>Number of Games Publishing=%{y}<extra></extra>", "legendgroup": "NA_Sales", "marker": {"color": "#636efa"}, "name": "NA_Sales", "offsetgroup": "NA_Sales", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Nintendo", "Electronic Arts", "Activision", "Sony Computer Entertainment", "Ubisoft", "Take-Two Interactive", "THQ", "Microsoft Game Studios", "Sega", "Atari"], "xaxis": "x", "y": [815.7500000000001, 584.2199999999979, 426.0099999999991, 265.2199999999993, 252.81000000000046, 220.47000000000048, 208.6000000000004, 155.35000000000008, 108.77999999999996, 101.22999999999989], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], ...

# %%
#according to north america game sales
max_osales_publisher = publisher_sales.sort_values(["Other_Sales"]).tail(10)
tops_publisher_osales = max_osales_publisher.iloc[::-1]
tops_publisher_osales
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Electronic Arts                 584.22    367.38     13.98       127.63
# Nintendo                        815.75    418.30    454.99        95.19
# Sony Computer Entertainment     265.22    187.55     74.10        80.40
# Activision                      426.01    213.72      6.54        74.79
# Take-Two Interactive            220.47    117.95      5.83        55.20
# Ubisoft                         252.81    163.03      7.33        50.16
# THQ                             208.60     94.60      5.01        32.11
# Konami Digital Entertainment     88.91     68.62     90.93        29.91
# Sega                            108.78     81.41     56.19        24.30
# Microsoft Game Studios          155.35     68.61      3.26        18.56
#
#                               Global_Sales
# Publisher
# Electronic Arts                    1093.39
# Nintendo                           1784.43
# Sony Computer Entertainment         607.28
# Activision                          721.41
# Take-Two Interactive                399.30
# Ubisoft                             473.54
# THQ                                 340.44
# Konami Digital Entertainment        278.56
# Sega                                270.70
# Microsoft Game Studios              245.79

# %%
px.bar(tops_publisher_osales["Other_Sales"], title= "Top 10 Video Game Publishers According To Game Sales in Other Regions",
      labels={
          "value" : "Number of Games Publishing",
          "index" : "Name of the Publisher"
      })
# Out:
# <div>                            <div id="1af779a2-cbeb-4e4f-be00-83dfe7c968c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1af779a2-cbeb-4e4f-be00-83dfe7c968c6")) {                    Plotly.newPlot(                        "1af779a2-cbeb-4e4f-be00-83dfe7c968c6",                        [{"alignmentgroup": "True", "hovertemplate": "variable=Other_Sales<br>Publisher=%{x}<br>Number of Games Publishing=%{y}<extra></extra>", "legendgroup": "Other_Sales", "marker": {"color": "#636efa"}, "name": "Other_Sales", "offsetgroup": "Other_Sales", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Electronic Arts", "Nintendo", "Sony Computer Entertainment", "Activision", "Take-Two Interactive", "Ubisoft", "THQ", "Konami Digital Entertainment", "Sega", "Microsoft Game Studios"], "xaxis": "x", "y": [127.63000000000072, 95.19000000000037, 80.4000000000002, 74.79000000000089, 55.19999999999992, 50.15999999999995, 32.11000000000025, 29.910000000000235, 24.30000000000012, 18.560000000000073], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"],  ...

# %%
#global sales according to years
figs = []
game_sales_inyears = games.groupby(['Year','Publisher'], as_index=False)['Global_Sales'].sum()
top_gallsales_inyears = pd.DataFrame()

for i in range(len(years)):
    if i == 0:
        top_gallsales_inyears = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "Global_Sales",
                                                                                                   ascending = False).head(2)
        
    else:
        df = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "Global_Sales",
                                                                                    ascending = False).head(2)
        top_gallsales_inyears = top_gallsales_inyears.append(df, ignore_index=True)

top_gallsales_inyears
# Out:
#       Year        Publisher  Global_Sales
# 0   1980.0            Atari          8.36
# 1   1980.0       Activision          3.02
# 2   1981.0       Activision          8.50
# 3   1981.0            Atari          8.45
# 4   1982.0            Atari         19.43
# ..     ...              ...           ...
# 72  2016.0  Electronic Arts         12.25
# 73  2016.0          Ubisoft          9.76
# 74  2017.0             Sega          0.04
# 75  2017.0     Idea Factory          0.01
# 76  2020.0          Ubisoft          0.29
#
# [77 rows x 3 columns]

# %%
publishers = top_gallsales_inyears.Publisher.unique()
for p in range(len(publishers)):
    figs.append(go.Scatter(x = years, y=top_gallsales_inyears.Global_Sales[top_gallsales_inyears.Publisher == publishers[p]],
                           name=publishers[p], line_shape="vh"))
     
    
layout = dict(title="Year Wise Global Game Sales According to Years",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="8005a176-b9d7-4545-9080-39a99a0f1a25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8005a176-b9d7-4545-9080-39a99a0f1a25")) {                    Plotly.newPlot(                        "8005a176-b9d7-4545-9080-39a99a0f1a25",                        [{"line": {"shape": "vh"}, "name": "Atari", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [8.36, 8.450000000000001, 19.43, 3.3899999999999997]}, {"line": {"shape": "vh"}, "name": "Activision", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [3.02, 8.5, 1.8599999999999999, 63.390000000000015, 51.740000000000016, 53.25, 35.63000000000001]}, {"line": {"shape": "vh"}, "name": "Nintendo", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [10.959999999999999, 45.56000000000001, 49.95, 16.18, 11.950000000000001, 36.440000000000005, 63.88000000000001, 35.49, 15.97, 38.10999999999999, 20.04, 24.99, 16.719999999999995, 73.69999999999999, 25.8, 48.41, 65.33000000000001, 34.050000000000004, 45.37000000000002, 48.30999999999999, 38.13999999999999, 60.65000000000001, 127.46999999999998, 205.60999999999999, 104.18, 91.22000000000004, 128.89, 56.470000000000006, 52.790000000000006, 48.64999999999999]}, {"line": {"shape": "vh"}, "name": "Namco Bandai Games", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [3.43, 1.46, 2.67, 5.38]}, {"line": {"shape": "vh"}, "name": "Capcom", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [5.3, 3.92, 12.399999999999999]}, {"line": {"shape": "vh"}, "name": "Enix Corporation", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [3.87]}, {"line": {"shape": "vh"}, "name": "Palcom", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [4.17]}, {"line": {"shape": "vh"}, "name": "S ...

# %%
fig = px.scatter(top_gallsales_inyears, x="Global_Sales", y="Year", color="Publisher", size="Global_Sales",
                hover_data=["Publisher"], title="All Year Wise Global Game Sales In Millions According to Years",
                labels={"x": "Global_Sales", "y": "Year"})
fig.show()
# Out:
# <div>                            <div id="d358d431-aadf-4a8d-95be-673e55f0a312" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d358d431-aadf-4a8d-95be-673e55f0a312")) {                    Plotly.newPlot(                        "d358d431-aadf-4a8d-95be-673e55f0a312",                        [{"customdata": [["Atari"], ["Atari"], ["Atari"], ["Atari"]], "hovertemplate": "Publisher=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Atari", "marker": {"color": "#636efa", "size": [8.36, 8.450000000000001, 19.43, 3.3899999999999997], "sizemode": "area", "sizeref": 0.514025, "symbol": "circle"}, "mode": "markers", "name": "Atari", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.36, 8.450000000000001, 19.43, 3.3899999999999997], "xaxis": "x", "y": [1980.0, 1981.0, 1982.0, 1983.0], "yaxis": "y"}, {"customdata": [["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"]], "hovertemplate": "Publisher=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Activision", "marker": {"color": "#EF553B", "size": [3.02, 8.5, 1.8599999999999999, 63.390000000000015, 51.740000000000016, 53.25, 35.63000000000001], "sizemode": "area", "sizeref": 0.514025, "symbol": "circle"}, "mode": "markers", "name": "Activision", "orientation": "v", "showlegend": true, "type": "scatter", "x": [3.02, 8.5, 1.8599999999999999, 63.390000000000015, 51.740000000000016, 53.25, 35.63000000000001], "xaxis": "x", "y": [1980.0, 1981.0, 1982.0, 2010.0, 2011.0, 2012.0, 2015.0], "yaxis": "y"}, {"customdata": [["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"]], "hovertemplate": "Publisher=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Nintendo", "marker": {"color": "#00cc96", "size": [10.959999999999999, 45.56000000000001, 49.95, 16.18, 11.950000000000001, 36.440000000000005, 63.88000000000001, 35.49, 15.97, 38.10999999999999, 20.04, 24.99, 16.719999999999995, 73.69999999999999, 25.8, 48.41, 65.33000000000001, 34.050000000000004, 45.37000000000002, 48.30999999999999, 38.13999999999999, 60.65000000000001, 127.46999999999998, 205.60999999999999, 104.18, 91.22000000000004, 128.89, 56.470000000000006, 52.790000000000006, 48.64999999999999], "sizemode": "area", "sizeref": 0.514025, "symbol": "circle"}, "mode": "markers", "name": "Nintendo", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.959999999999999, 45.56000000000001, 49.95, 16.18, 11.950000000000001, 36.440000000000005, 63.88000000000001, 35.49, 15.97, 38.10999999999999, 20.04, 24.99, 16.719999999999995, 73.69999999999999, 25.8, 48.41, 65.33000000000001, 34.050000000000004, 45.37000000000002, 48.30999999999999, 38.13999999999999, 60.65000000000001, 127.46999999999998, 205.60999999999999, 104.18, 91.22000000000004, 128.89, 56.470000000000006, 52.790000000000006, 48.64999999999999], "xaxis": "x", "y": [1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2012.0, 2013.0, 2014.0], "yaxis": "y"}, {"customdata": [["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"]], "hovertemplate": "Publisher=%{customdata[0]}<br>Global ...

# %%
figs = []
for i in range(20,31):
    if i == 20:
        top_gsales_inyears = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "Global_Sales",
                                                                                                   ascending = False).head(5)
        
    else:
        df = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "Global_Sales",
                                                                                    ascending = False).head(5)
        top_gsales_inyears = top_gsales_inyears.append(df, ignore_index=True)

publishers = top_gsales_inyears.Publisher.unique()
for p in range(len(publishers)):
    figs.append(go.Scatter(x = years[20:31], y=top_gsales_inyears.Global_Sales[top_gsales_inyears.Publisher == publishers[p]],
                           name=publishers[p], line_shape="vh"))
     
        
layout = dict(title="Year Wise Global Game Sales According to Years",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="da5fc429-30df-4184-8f36-cd61d09434c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da5fc429-30df-4184-8f36-cd61d09434c1")) {                    Plotly.newPlot(                        "da5fc429-30df-4184-8f36-cd61d09434c1",                        [{"line": {"shape": "vh"}, "name": "Nintendo", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [34.050000000000004, 45.37000000000002, 48.30999999999999, 38.13999999999999, 60.65000000000001, 127.46999999999998, 205.60999999999999, 104.18, 91.22000000000004, 128.89, 61.07]}, {"line": {"shape": "vh"}, "name": "Electronic Arts", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [25.13, 45.12000000000001, 73.01000000000002, 69.82999999999998, 67.33000000000003, 67.01000000000002, 58.410000000000025, 71.33, 84.12, 86.20000000000002, 81.38000000000001]}, {"line": {"shape": "vh"}, "name": "Sony Computer Entertainment", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [21.689999999999994, 43.29, 25.850000000000012, 24.319999999999997, 35.16000000000002, 26.38, 33.81, 37.54000000000002, 36.53]}, {"line": {"shape": "vh"}, "name": "THQ", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [15.859999999999998, 22.250000000000004, 26.880000000000003, 29.380000000000003, 28.689999999999994, 24.939999999999998]}, {"line": {"shape": "vh"}, "name": "Activision", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [14.48, 25.939999999999994, 21.380000000000006, 39.23, 35.390000000000015, 63.57, 67.40999999999997, 78.05999999999997, 63.390000000000015]}, {"line": {"shape": "vh"}, "name": "Konami Digital Entertainment", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [21.889999999999997]}, {"line": {"shape": "vh"}, "name": "Take-Two Interactive", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [26.29, 20.59, 46.180000000000014]}, {"line": {"shape": "vh"}, "name": "Ubisoft", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [48.59999999999997, 57.43999999999999, 47.01000000000001, 42.61999999999998]}, {"line": {"shape": "vh"}, "name": "Microsoft Game Studios", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [49.160000000000004]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"] ...

# %%
fig = px.scatter(top_gsales_inyears, x="Global_Sales", y="Year", color="Publisher", size="Global_Sales",
                hover_data=["Publisher"], title="Year Wise Global Game Sales In Millions According to Years",
                labels={"x": "Global_Sales", "y": "Year"})
fig.show()
# Out:
# <div>                            <div id="ffb7e03c-ad24-4d9b-901c-4277840d1378" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffb7e03c-ad24-4d9b-901c-4277840d1378")) {                    Plotly.newPlot(                        "ffb7e03c-ad24-4d9b-901c-4277840d1378",                        [{"customdata": [["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"]], "hovertemplate": "Publisher=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Nintendo", "marker": {"color": "#636efa", "size": [34.050000000000004, 45.37000000000002, 48.30999999999999, 38.13999999999999, 60.65000000000001, 127.46999999999998, 205.60999999999999, 104.18, 91.22000000000004, 128.89, 61.07], "sizemode": "area", "sizeref": 0.514025, "symbol": "circle"}, "mode": "markers", "name": "Nintendo", "orientation": "v", "showlegend": true, "type": "scatter", "x": [34.050000000000004, 45.37000000000002, 48.30999999999999, 38.13999999999999, 60.65000000000001, 127.46999999999998, 205.60999999999999, 104.18, 91.22000000000004, 128.89, 61.07], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"]], "hovertemplate": "Publisher=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Electronic Arts", "marker": {"color": "#EF553B", "size": [25.13, 45.12000000000001, 73.01000000000002, 69.82999999999998, 67.33000000000003, 67.01000000000002, 58.410000000000025, 71.33, 84.12, 86.20000000000002, 81.38000000000001], "sizemode": "area", "sizeref": 0.514025, "symbol": "circle"}, "mode": "markers", "name": "Electronic Arts", "orientation": "v", "showlegend": true, "type": "scatter", "x": [25.13, 45.12000000000001, 73.01000000000002, 69.82999999999998, 67.33000000000003, 67.01000000000002, 58.410000000000025, 71.33, 84.12, 86.20000000000002, 81.38000000000001], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"]], "hovertemplate": "Publisher=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Sony Computer Entertainment", "marker": {"color": "#00cc96", "size": [21.689999999999994, 43.29, 25.850000000000012, 24.319999999999997, 35.16000000000002, 26.38, 33.81, 37.54000000000002, 36.53], "sizemode": "area", "sizeref": 0.514025, "symbol": "circle"}, "mode": "markers", "name": "Sony Computer Entertainment", "orientation": "v", "showlegend": true, "type": "scatter", "x": [21.689999999999994, 43.29, 25.850000000000012, 24.319999999999997, 35.16000000000002, 26.38, 33.81, 37.54000000000002, 36.53], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2009.0], "yaxis": "y"}, {"customdata": [["THQ"], ["THQ"], ["THQ"], ["THQ"], ["THQ"], ["THQ"]], "hovertemplate": "Publisher=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "THQ", "marker": {"color": "#ab63fa", "size": [15.859999999999998, 22.250000000000004, 26.880000000000003, 29.380000000000003, 28.689999999999994, 24.9399999 ...

# %%
game09 = games[games.Year == 2009]
global_val = top_gsales_inyears.Publisher[top_gsales_inyears.Year == 2009]
values = pd.DataFrame()
result = pd.DataFrame()
for i in range(len(global_val)):
    if i == 0:
        values = game09[game09.Publisher == global_val.iloc[i]]
        result = values[values.Global_Sales == values.Global_Sales.max()]
    else:
        values = game09[game09.Publisher == global_val.iloc[i]]
        result = result.append(values[values.Global_Sales == values.Global_Sales.max()])

fig = px.sunburst(result, path = ["Name", "Genre", "Publisher"], values = result["Global_Sales"],
                      title="Best Selling Games of the Top 5 Publishers in Global in 2009 and Their Genres")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="b3956afa-d031-48c4-a8d3-1dc324c76a1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3956afa-d031-48c4-a8d3-1dc324c76a1f")) {                    Plotly.newPlot(                        "b3956afa-d031-48c4-a8d3-1dc324c76a1f",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Call of Duty: Modern Warfare 2/Shooter/Activision", "The Sims 3/Simulation/Electronic Arts", "Wii Sports Resort/Sports/Nintendo", "Uncharted 2: Among Thieves/Action/Sony Computer Entertainment", "Just Dance/Misc/Ubisoft", "Uncharted 2: Among Thieves/Action", "Just Dance/Misc", "Call of Duty: Modern Warfare 2/Shooter", "The Sims 3/Simulation", "Wii Sports Resort/Sports", "Call of Duty: Modern Warfare 2", "Just Dance", "The Sims 3", "Uncharted 2: Among Thieves", "Wii Sports Resort"], "labels": ["Activision", "Electronic Arts", "Nintendo", "Sony Computer Entertainment", "Ubisoft", "Action", "Misc", "Shooter", "Simulation", "Sports", "Call of Duty: Modern Warfare 2", "Just Dance", "The Sims 3", "Uncharted 2: Among Thieves", "Wii Sports Resort"], "name": "", "parents": ["Call of Duty: Modern Warfare 2/Shooter", "The Sims 3/Simulation", "Wii Sports Resort/Sports", "Uncharted 2: Among Thieves/Action", "Just Dance/Misc", "Uncharted 2: Among Thieves", "Just Dance", "Call of Duty: Modern Warfare 2", "The Sims 3", "Wii Sports Resort", "", "", "", "", ""], "type": "sunburst", "values": [13.51, 8.11, 33.0, 6.73, 7.27, 6.73, 7.27, 13.51, 8.11, 33.0, 13.51, 7.27, 8.11, 6.73, 33.0]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{" ...

# %%
figs = []
game_sales_inyears = games.groupby(['Year','Publisher'], as_index=False)['JP_Sales'].sum()
top_jsales_inyears = pd.DataFrame()
for i in range(20,31):
    if i == 20:
        top_jsales_inyears = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "JP_Sales",
                                                                                                   ascending = False).head(5)
        
    else:
        df = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "JP_Sales",
                                                                                    ascending = False).head(5)
        top_jsales_inyears = top_jsales_inyears.append(df, ignore_index=True)

publishers = top_jsales_inyears.Publisher.unique()
for p in range(len(publishers)):
    figs.append(go.Scatter(x = years[20:31], y=top_jsales_inyears.JP_Sales[top_jsales_inyears.Publisher == publishers[p]],
                           name=publishers[p], line_shape="vh"))
     
        
layout = dict(title="Year Wise Game Sales in Japan According to Years",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="18f1bd2b-40df-41b6-a1ec-8a417ed2b12d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18f1bd2b-40df-41b6-a1ec-8a417ed2b12d")) {                    Plotly.newPlot(                        "18f1bd2b-40df-41b6-a1ec-8a417ed2b12d",                        [{"line": {"shape": "vh"}, "name": "Nintendo", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [10.53, 11.150000000000002, 11.900000000000002, 9.849999999999998, 17.47, 29.499999999999993, 36.74, 19.980000000000004, 19.959999999999997, 29.82, 16.3]}, {"line": {"shape": "vh"}, "name": "Konami Digital Entertainment", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [6.639999999999999, 3.8399999999999994, 3.5300000000000002, 2.5900000000000003, 4.17, 3.2099999999999995, 4.709999999999998, 4.359999999999996, 5.909999999999999, 3.4499999999999997, 5.919999999999997]}, {"line": {"shape": "vh"}, "name": "Enix Corporation", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [4.99, 2.9]}, {"line": {"shape": "vh"}, "name": "SquareSoft", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [4.03]}, {"line": {"shape": "vh"}, "name": "Namco Bandai Games", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [3.8899999999999997, 5.56, 3.7100000000000004, 1.8000000000000003, 2.9799999999999995, 5.969999999999996, 5.589999999999999, 6.7399999999999975, 6.789999999999999, 6.709999999999996]}, {"line": {"shape": "vh"}, "name": "Sony Computer Entertainment", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [6.4799999999999995, 3.63, 2.61]}, {"line": {"shape": "vh"}, "name": "Capcom", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [1.9, 3.48, 2.6299999999999994, 3.57, 4.029999999999999, 5.419999999999998, 7.280000000000001]}, {"line": {"shape": "vh"}, "name": "Electronic Arts", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [2.3799999999999994]}, {"line": {"shape": "vh"}, "name": "Square Enix", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [4.52, 2.9, 6.77, 6.31, 3.949999999999999, 3.6599999999999997, 4.079999999999999]}, {"line": {"shape": "vh"}, "name": "Sega", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [4.399999999999998, 3.339999999999999]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0. ...

# %%
fig = px.scatter(top_jsales_inyears, x="JP_Sales", y="Year", color="Publisher", size="JP_Sales",
                hover_data=["Publisher"], title="Year Wise Game Sales In Japan In Millions According to Years",
                labels={"x": "JP_Sales", "y": "Year"})
fig.show()
# Out:
# <div>                            <div id="2ba2b861-582d-40c0-926c-c8e1e3e7e5cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ba2b861-582d-40c0-926c-c8e1e3e7e5cf")) {                    Plotly.newPlot(                        "2ba2b861-582d-40c0-926c-c8e1e3e7e5cf",                        [{"customdata": [["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"]], "hovertemplate": "Publisher=%{customdata[0]}<br>JP_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Nintendo", "marker": {"color": "#636efa", "size": [10.53, 11.150000000000002, 11.900000000000002, 9.849999999999998, 17.47, 29.499999999999993, 36.74, 19.980000000000004, 19.959999999999997, 29.82, 16.3], "sizemode": "area", "sizeref": 0.09185, "symbol": "circle"}, "mode": "markers", "name": "Nintendo", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.53, 11.150000000000002, 11.900000000000002, 9.849999999999998, 17.47, 29.499999999999993, 36.74, 19.980000000000004, 19.959999999999997, 29.82, 16.3], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"], ["Konami Digital Entertainment"]], "hovertemplate": "Publisher=%{customdata[0]}<br>JP_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Konami Digital Entertainment", "marker": {"color": "#EF553B", "size": [6.639999999999999, 3.8399999999999994, 3.5300000000000002, 2.5900000000000003, 4.17, 3.2099999999999995, 4.709999999999998, 4.359999999999996, 5.909999999999999, 3.4499999999999997, 5.919999999999997], "sizemode": "area", "sizeref": 0.09185, "symbol": "circle"}, "mode": "markers", "name": "Konami Digital Entertainment", "orientation": "v", "showlegend": true, "type": "scatter", "x": [6.639999999999999, 3.8399999999999994, 3.5300000000000002, 2.5900000000000003, 4.17, 3.2099999999999995, 4.709999999999998, 4.359999999999996, 5.909999999999999, 3.4499999999999997, 5.919999999999997], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["Enix Corporation"], ["Enix Corporation"]], "hovertemplate": "Publisher=%{customdata[0]}<br>JP_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Enix Corporation", "marker": {"color": "#00cc96", "size": [4.99, 2.9], "sizemode": "area", "sizeref": 0.09185, "symbol": "circle"}, "mode": "markers", "name": "Enix Corporation", "orientation": "v", "showlegend": true, "type": "scatter", "x": [4.99, 2.9], "xaxis": "x", "y": [2000.0, 2001.0], "yaxis": "y"}, {"customdata": [["SquareSoft"]], "hovertemplate": "Publisher=%{customdata[0]}<br>JP_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "SquareSoft", "marker": {"color": "#ab63fa", "size": [4.03], "sizemode": "area", "sizeref": 0.09185, "symbol": "circle"}, "mode": "markers", "name": "SquareSoft", "orientation": "v", "showlegend": true, "type": "scatter", "x": [4.03], "xaxis": "x", "y": [2000.0], "yaxis": "y"}, {"customdata": [["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"], ["Namco Bandai Games"]], "hovertemplate": "Publisher=%{customdata[0]}<br>JP_Sales=%{marker. ...

# %%
game09 = games[games.Year == 2009]
japan_val = top_jsales_inyears.Publisher[top_jsales_inyears.Year == 2009]
values = pd.DataFrame()
result = pd.DataFrame()
for i in range(len(japan_val)):
    if i == 0:
        values = game09[game09.Publisher == japan_val.iloc[i]]
        result = values[values.JP_Sales == values.JP_Sales.max()]
    else:
        values = game09[game09.Publisher == japan_val.iloc[i]]
        result = result.append(values[values.JP_Sales == values.JP_Sales.max()])

fig = px.sunburst(result, path = ["Name", "Genre", "Publisher"], values = result["JP_Sales"],
                      title="Best Selling Games of the Top 5 Publishers in Japan in 2009 and Their Genres")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="dc14df90-8928-4645-bb6a-f2679da70582" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc14df90-8928-4645-bb6a-f2679da70582")) {                    Plotly.newPlot(                        "dc14df90-8928-4645-bb6a-f2679da70582",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>JP_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Pro Evolution Soccer 2010/Sports/Konami Digital Entertainment", "Tales of Vesperia/Role-Playing/Namco Bandai Games", "New Super Mario Bros. Wii/Platform/Nintendo", "Yakuza 3/Action/Sega", "Phantasy Star Portable 2/Role-Playing/Sega", "Final Fantasy XIII/Role-Playing/Square Enix", "Yakuza 3/Action", "New Super Mario Bros. Wii/Platform", "Final Fantasy XIII/Role-Playing", "Phantasy Star Portable 2/Role-Playing", "Tales of Vesperia/Role-Playing", "Pro Evolution Soccer 2010/Sports", "Final Fantasy XIII", "New Super Mario Bros. Wii", "Phantasy Star Portable 2", "Pro Evolution Soccer 2010", "Tales of Vesperia", "Yakuza 3"], "labels": ["Konami Digital Entertainment", "Namco Bandai Games", "Nintendo", "Sega", "Sega", "Square Enix", "Action", "Platform", "Role-Playing", "Role-Playing", "Role-Playing", "Sports", "Final Fantasy XIII", "New Super Mario Bros. Wii", "Phantasy Star Portable 2", "Pro Evolution Soccer 2010", "Tales of Vesperia", "Yakuza 3"], "name": "", "parents": ["Pro Evolution Soccer 2010/Sports", "Tales of Vesperia/Role-Playing", "New Super Mario Bros. Wii/Platform", "Yakuza 3/Action", "Phantasy Star Portable 2/Role-Playing", "Final Fantasy XIII/Role-Playing", "Yakuza 3", "New Super Mario Bros. Wii", "Final Fantasy XIII", "Phantasy Star Portable 2", "Tales of Vesperia", "Pro Evolution Soccer 2010", "", "", "", "", "", ""], "type": "sunburst", "values": [0.46, 0.45, 4.7, 0.62, 0.62, 1.87, 0.62, 4.7, 1.87, 0.62, 0.45, 0.46, 1.87, 4.7, 0.62, 0.46, 0.45, 0.62]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#460 ...

# %%
figs = []
game_sales_inyears = games.groupby(['Year','Publisher'], as_index=False)['EU_Sales'].sum()
top_eusales_inyears = pd.DataFrame()
for i in range(20,31):
    if i == 20:
        top_eusales_inyears = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "EU_Sales",
                                                                                                   ascending = False).head(5)
        
    else:
        df = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "EU_Sales",
                                                                                    ascending = False).head(5)
        top_eusales_inyears = top_eusales_inyears.append(df, ignore_index=True)

publishers = top_eusales_inyears.Publisher.unique()
for p in range(len(publishers)):
    figs.append(go.Scatter(x = years[20:31], y=top_eusales_inyears.EU_Sales[top_eusales_inyears.Publisher == publishers[p]],
                           name=publishers[p], line_shape="vh"))
     
        
layout = dict(title="Year Wise Game Sales in Europe According to Years",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="4b92d65b-3d06-4dfc-8c4a-b14e744a8117" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b92d65b-3d06-4dfc-8c4a-b14e744a8117")) {                    Plotly.newPlot(                        "4b92d65b-3d06-4dfc-8c4a-b14e744a8117",                        [{"line": {"shape": "vh"}, "name": "Sony Computer Entertainment", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [7.679999999999999, 12.64, 7.319999999999998, 8.68, 8.680000000000001, 5.92, 11.989999999999997, 11.649999999999999, 13.359999999999998, 12.750000000000002]}, {"line": {"shape": "vh"}, "name": "Electronic Arts", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [7.14, 14.459999999999997, 24.370000000000008, 21.109999999999996, 18.88000000000001, 13.489999999999984, 13.219999999999986, 20.670000000000016, 25.590000000000003, 30.970000000000024, 31.180000000000017]}, {"line": {"shape": "vh"}, "name": "Nintendo", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [6.42, 8.840000000000002, 9.889999999999999, 7.080000000000001, 12.43, 42.69000000000002, 60.35000000000001, 32.809999999999995, 25.130000000000003, 36.18, 16.52]}, {"line": {"shape": "vh"}, "name": "THQ", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [5.299999999999999, 8.01, 8.239999999999995, 8.629999999999992, 8.819999999999997, 5.689999999999995]}, {"line": {"shape": "vh"}, "name": "Activision", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [4.499999999999999, 7.749999999999997, 6.399999999999997, 16.240000000000002, 7.779999999999995, 13.479999999999988, 16.190000000000005, 21.88000000000001, 16.88000000000001]}, {"line": {"shape": "vh"}, "name": "Take-Two Interactive", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [6.819999999999999, 8.429999999999994, 5.609999999999999, 13.779999999999994]}, {"line": {"shape": "vh"}, "name": "Ubisoft", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [15.019999999999985, 18.96000000000004, 14.969999999999988, 13.979999999999993]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.22222222 ...

# %%
fig = px.scatter(top_eusales_inyears, x="EU_Sales", y="Year", color="Publisher", size="EU_Sales",
                hover_data=["Publisher"], title="Year Wise Game Sales In Europe In Millions According to Years",
                labels={"x": "EU_Sales", "y": "Year"})
fig.show()
# Out:
# <div>                            <div id="6d3c5677-fe03-4c34-9737-729e13a09cab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d3c5677-fe03-4c34-9737-729e13a09cab")) {                    Plotly.newPlot(                        "6d3c5677-fe03-4c34-9737-729e13a09cab",                        [{"customdata": [["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"]], "hovertemplate": "Publisher=%{customdata[0]}<br>EU_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Sony Computer Entertainment", "marker": {"color": "#636efa", "size": [7.679999999999999, 12.64, 7.319999999999998, 8.68, 8.680000000000001, 5.92, 11.989999999999997, 11.649999999999999, 13.359999999999998, 12.750000000000002], "sizemode": "area", "sizeref": 0.150875, "symbol": "circle"}, "mode": "markers", "name": "Sony Computer Entertainment", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.679999999999999, 12.64, 7.319999999999998, 8.68, 8.680000000000001, 5.92, 11.989999999999997, 11.649999999999999, 13.359999999999998, 12.750000000000002], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"]], "hovertemplate": "Publisher=%{customdata[0]}<br>EU_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Electronic Arts", "marker": {"color": "#EF553B", "size": [7.14, 14.459999999999997, 24.370000000000008, 21.109999999999996, 18.88000000000001, 13.489999999999984, 13.219999999999986, 20.670000000000016, 25.590000000000003, 30.970000000000024, 31.180000000000017], "sizemode": "area", "sizeref": 0.150875, "symbol": "circle"}, "mode": "markers", "name": "Electronic Arts", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.14, 14.459999999999997, 24.370000000000008, 21.109999999999996, 18.88000000000001, 13.489999999999984, 13.219999999999986, 20.670000000000016, 25.590000000000003, 30.970000000000024, 31.180000000000017], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"]], "hovertemplate": "Publisher=%{customdata[0]}<br>EU_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Nintendo", "marker": {"color": "#00cc96", "size": [6.42, 8.840000000000002, 9.889999999999999, 7.080000000000001, 12.43, 42.69000000000002, 60.35000000000001, 32.809999999999995, 25.130000000000003, 36.18, 16.52], "sizemode": "area", "sizeref": 0.150875, "symbol": "circle"}, "mode": "markers", "name": "Nintendo", "orientation": "v", "showlegend": true, "type": "scatter", "x": [6.42, 8.840000000000002, 9.889999999999999, 7.080000000000001, 12.43, 42.69000000000002, 60.35000000000001, 32.809999999999995, 25.130000000000003, 36.18, 16.52], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["THQ"], ["THQ"], ["THQ"], ["THQ"], ["THQ"], ["THQ"]], "hovertemplate": "Publisher=%{customdata[0]}<br>EU_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "THQ", "marker": {"color": "#ab63fa", "siz ...

# %%
game09 = games[games.Year == 2009]
eu_val = top_eusales_inyears.Publisher[top_eusales_inyears.Year == 2009]
values = pd.DataFrame()
result = pd.DataFrame()
for i in range(len(eu_val)):
    if i == 0:
        values = game09[game09.Publisher == eu_val.iloc[i]]
        result = values[values.EU_Sales == values.EU_Sales.max()]
    else:
        values = game09[game09.Publisher == eu_val.iloc[i]]
        result = result.append(values[values.EU_Sales == values.EU_Sales.max()])

fig = px.sunburst(result, path = ["Name", "Genre", "Publisher"], values = result["EU_Sales"],
                      title="Best Selling Games of the Top 5 Publishers in Europe in 2009 and Their Genres")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="8b0927eb-2a33-41d9-8535-28ddd78e4a0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b0927eb-2a33-41d9-8535-28ddd78e4a0c")) {                    Plotly.newPlot(                        "8b0927eb-2a33-41d9-8535-28ddd78e4a0c",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>EU_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Call of Duty: Modern Warfare 2/Shooter/Activision", "The Sims 3/Simulation/Electronic Arts", "Wii Sports Resort/Sports/Nintendo", "Uncharted 2: Among Thieves/Action/Sony Computer Entertainment", "Just Dance/Misc/Ubisoft", "Uncharted 2: Among Thieves/Action", "Just Dance/Misc", "Call of Duty: Modern Warfare 2/Shooter", "The Sims 3/Simulation", "Wii Sports Resort/Sports", "Call of Duty: Modern Warfare 2", "Just Dance", "The Sims 3", "Uncharted 2: Among Thieves", "Wii Sports Resort"], "labels": ["Activision", "Electronic Arts", "Nintendo", "Sony Computer Entertainment", "Ubisoft", "Action", "Misc", "Shooter", "Simulation", "Sports", "Call of Duty: Modern Warfare 2", "Just Dance", "The Sims 3", "Uncharted 2: Among Thieves", "Wii Sports Resort"], "name": "", "parents": ["Call of Duty: Modern Warfare 2/Shooter", "The Sims 3/Simulation", "Wii Sports Resort/Sports", "Uncharted 2: Among Thieves/Action", "Just Dance/Misc", "Uncharted 2: Among Thieves", "Just Dance", "Call of Duty: Modern Warfare 2", "The Sims 3", "Wii Sports Resort", "", "", "", "", ""], "type": "sunburst", "values": [3.69, 6.42, 11.01, 2.25, 3.03, 2.25, 3.03, 3.69, 6.42, 11.01, 3.69, 3.03, 6.42, 2.25, 11.01]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"mark ...

# %%
figs = []
game_sales_inyears = games.groupby(['Year','Publisher'], as_index=False)['NA_Sales'].sum()
top_nasales_inyears = pd.DataFrame()
for i in range(20,31):
    if i == 20:
        top_nasales_inyears = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "NA_Sales",
                                                                                                   ascending = False).head(5)
        
    else:
        df = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "NA_Sales",
                                                                                    ascending = False).head(5)
        top_nasales_inyears = top_nasales_inyears.append(df, ignore_index=True)

publishers = top_nasales_inyears.Publisher.unique()
for p in range(len(publishers)):
    figs.append(go.Scatter(x = years[20:31], y=top_nasales_inyears.NA_Sales[top_nasales_inyears.Publisher == publishers[p]],
                           name=publishers[p], line_shape="vh"))
     
        
layout = dict(title="Year Wise Game Sales in North America According to Years",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="5ab5bbc2-5ffb-43d1-a621-95a9f143657d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ab5bbc2-5ffb-43d1-a621-95a9f143657d")) {                    Plotly.newPlot(                        "5ab5bbc2-5ffb-43d1-a621-95a9f143657d",                        [{"line": {"shape": "vh"}, "name": "Electronic Arts", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [15.09, 26.210000000000008, 40.7, 40.47, 41.010000000000005, 46.80999999999998, 37.34000000000007, 36.76, 45.1, 43.25999999999999, 39.23999999999998]}, {"line": {"shape": "vh"}, "name": "Nintendo", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [15.0, 23.84, 25.05, 20.149999999999995, 28.300000000000004, 45.05, 90.35, 42.77, 38.83000000000001, 53.149999999999984, 24.179999999999993]}, {"line": {"shape": "vh"}, "name": "Sony Computer Entertainment", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [11.020000000000005, 20.98, 11.209999999999997, 13.059999999999999, 14.729999999999995, 13.999999999999995]}, {"line": {"shape": "vh"}, "name": "Activision", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [9.31, 16.34, 13.159999999999997, 20.729999999999997, 24.87000000000001, 13.009999999999991, 42.08999999999998, 40.830000000000005, 45.63000000000003, 39.489999999999974]}, {"line": {"shape": "vh"}, "name": "THQ", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [9.25, 11.420000000000002, 16.200000000000003, 18.769999999999992, 17.949999999999996, 15.579999999999997, 16.630000000000003, 20.12, 18.830000000000005]}, {"line": {"shape": "vh"}, "name": "Take-Two Interactive", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [11.440000000000001, 26.45999999999999]}, {"line": {"shape": "vh"}, "name": "Atari", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [13.73]}, {"line": {"shape": "vh"}, "name": "Ubisoft", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [27.640000000000015, 31.879999999999992, 26.34000000000001, 24.11999999999999]}, {"line": {"shape": "vh"}, "name": "Microsoft Game Studios", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [32.85]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type" ...

# %%
fig = px.scatter(top_nasales_inyears, x="NA_Sales", y="Year", color="Publisher", size="NA_Sales",
                hover_data=["Publisher"], title="Year Wise Game Sales In North America In Millions According to Years",
                labels={"x": "NA_Sales", "y": "Year"})
fig.show()
# Out:
# <div>                            <div id="baf2ccc1-7340-4db5-ab7d-08d074e58407" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("baf2ccc1-7340-4db5-ab7d-08d074e58407")) {                    Plotly.newPlot(                        "baf2ccc1-7340-4db5-ab7d-08d074e58407",                        [{"customdata": [["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"], ["Electronic Arts"]], "hovertemplate": "Publisher=%{customdata[0]}<br>NA_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Electronic Arts", "marker": {"color": "#636efa", "size": [15.09, 26.210000000000008, 40.7, 40.47, 41.010000000000005, 46.80999999999998, 37.34000000000007, 36.76, 45.1, 43.25999999999999, 39.23999999999998], "sizemode": "area", "sizeref": 0.225875, "symbol": "circle"}, "mode": "markers", "name": "Electronic Arts", "orientation": "v", "showlegend": true, "type": "scatter", "x": [15.09, 26.210000000000008, 40.7, 40.47, 41.010000000000005, 46.80999999999998, 37.34000000000007, 36.76, 45.1, 43.25999999999999, 39.23999999999998], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"], ["Nintendo"]], "hovertemplate": "Publisher=%{customdata[0]}<br>NA_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Nintendo", "marker": {"color": "#EF553B", "size": [15.0, 23.84, 25.05, 20.149999999999995, 28.300000000000004, 45.05, 90.35, 42.77, 38.83000000000001, 53.149999999999984, 24.179999999999993], "sizemode": "area", "sizeref": 0.225875, "symbol": "circle"}, "mode": "markers", "name": "Nintendo", "orientation": "v", "showlegend": true, "type": "scatter", "x": [15.0, 23.84, 25.05, 20.149999999999995, 28.300000000000004, 45.05, 90.35, 42.77, 38.83000000000001, 53.149999999999984, 24.179999999999993], "xaxis": "x", "y": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"], ["Sony Computer Entertainment"]], "hovertemplate": "Publisher=%{customdata[0]}<br>NA_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Sony Computer Entertainment", "marker": {"color": "#00cc96", "size": [11.020000000000005, 20.98, 11.209999999999997, 13.059999999999999, 14.729999999999995, 13.999999999999995], "sizemode": "area", "sizeref": 0.225875, "symbol": "circle"}, "mode": "markers", "name": "Sony Computer Entertainment", "orientation": "v", "showlegend": true, "type": "scatter", "x": [11.020000000000005, 20.98, 11.209999999999997, 13.059999999999999, 14.729999999999995, 13.999999999999995], "xaxis": "x", "y": [2000.0, 2001.0, 2003.0, 2004.0, 2005.0, 2006.0], "yaxis": "y"}, {"customdata": [["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"], ["Activision"]], "hovertemplate": "Publisher=%{customdata[0]}<br>NA_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Activision", "marker": {"color": "#ab63fa", "size": [9.31, 16.34, 13.159999999999997, 20.729999999999997, 24.87000000000001, 13.009999999999991, 42.08999999999998, 40.830000000000005, 45.63000000000003, 39.489999999999974], "sizemode": "area", "sizeref": 0.225875, "symbol": "circle"}, "mode": "markers", "name": "Activision", "orientation": "v", "showl ...

# %%
game09 = games[games.Year == 2009]
na_val = top_nasales_inyears.Publisher[top_nasales_inyears.Year == 2009]
values = pd.DataFrame()
result = pd.DataFrame()
for i in range(len(na_val)):
    if i == 0:
        values = game09[game09.Publisher == eu_val.iloc[i]]
        result = values[values.NA_Sales == values.NA_Sales.max()]
    else:
        values = game09[game09.Publisher == eu_val.iloc[i]]
        result = result.append(values[values.NA_Sales == values.NA_Sales.max()])

fig = px.sunburst(result, path = ["Name", "Genre", "Publisher"], values = result["NA_Sales"],
                      title="Best Selling Games of the Top 5 Publishers in North America in 2009 and Their Genres")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="233805e4-c33c-478f-8e53-2c09438c31da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("233805e4-c33c-478f-8e53-2c09438c31da")) {                    Plotly.newPlot(                        "233805e4-c33c-478f-8e53-2c09438c31da",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>NA_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Call of Duty: Modern Warfare 2/Shooter/Activision", "Left 4 Dead 2/Shooter/Electronic Arts", "Wii Sports Resort/Sports/Nintendo", "Uncharted 2: Among Thieves/Action/Sony Computer Entertainment", "Just Dance/Misc/Ubisoft", "Uncharted 2: Among Thieves/Action", "Just Dance/Misc", "Call of Duty: Modern Warfare 2/Shooter", "Left 4 Dead 2/Shooter", "Wii Sports Resort/Sports", "Call of Duty: Modern Warfare 2", "Just Dance", "Left 4 Dead 2", "Uncharted 2: Among Thieves", "Wii Sports Resort"], "labels": ["Activision", "Electronic Arts", "Nintendo", "Sony Computer Entertainment", "Ubisoft", "Action", "Misc", "Shooter", "Shooter", "Sports", "Call of Duty: Modern Warfare 2", "Just Dance", "Left 4 Dead 2", "Uncharted 2: Among Thieves", "Wii Sports Resort"], "name": "", "parents": ["Call of Duty: Modern Warfare 2/Shooter", "Left 4 Dead 2/Shooter", "Wii Sports Resort/Sports", "Uncharted 2: Among Thieves/Action", "Just Dance/Misc", "Uncharted 2: Among Thieves", "Just Dance", "Call of Duty: Modern Warfare 2", "Left 4 Dead 2", "Wii Sports Resort", "", "", "", "", ""], "type": "sunburst", "values": [8.52, 2.67, 15.75, 3.27, 3.51, 3.27, 3.51, 8.52, 2.67, 15.75, 8.52, 3.51, 2.67, 3.27, 15.75]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [ ...

# %%
figs = []
game_sales_inyears = games.loc[:,["Year", "Publisher", "Other_Sales"]].groupby(['Year','Publisher'], as_index=False)['Other_Sales'].sum()
top_osales_inyears = pd.DataFrame()
for i in range(20,31):
    if i == 20:
        top_osales_inyears = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "Other_Sales",
                                                                                                   ascending = False).head(5)
        
    else:
        df = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "Other_Sales",
                                                                                    ascending = False).head(5)
        top_osales_inyears = top_osales_inyears.append(df, ignore_index=True)

publishers = top_osales_inyears.Publisher.unique()
for p in range(len(publishers)):
    figs.append(go.Scatter(x = years[20:31], y=top_osales_inyears.Other_Sales[top_osales_inyears.Publisher == publishers[p]],
                           name=publishers[p], line_shape="vh"))
     
        
layout = dict(title="Year Wise Game Sales in Other Regions According to Years",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="ec386c5c-a6b7-4286-b7fb-7ab2b6a6d2f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec386c5c-a6b7-4286-b7fb-7ab2b6a6d2f1")) {                    Plotly.newPlot(                        "ec386c5c-a6b7-4286-b7fb-7ab2b6a6d2f1",                        [{"line": {"shape": "vh"}, "name": "Nintendo", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [2.0699999999999994, 1.5800000000000003, 2.4599999999999955, 10.129999999999988, 18.160000000000014, 8.599999999999994, 7.22, 9.709999999999994, 4.0699999999999985]}, {"line": {"shape": "vh"}, "name": "Electronic Arts", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [1.6800000000000006, 3.9799999999999973, 7.0999999999999925, 5.8199999999999905, 6.059999999999991, 6.349999999999985, 7.3999999999999915, 13.26999999999998, 12.64999999999999, 11.529999999999992, 10.35999999999999]}, {"line": {"shape": "vh"}, "name": "Sony Computer Entertainment", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y": [1.4500000000000004, 3.1999999999999975, 1.9100000000000008, 2.9199999999999973, 10.769999999999998, 4.269999999999994, 5.669999999999997, 8.279999999999996, 5.869999999999997, 7.929999999999997, 5.669999999999995]}, {"line": {"shape": "vh"}, "name": "THQ", "type": "scatter", "x": [2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "y":
000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0], "yaxis": "y"}, {"customdata": [["THQ"], ["THQ"], ["THQ"], ["THQ"]] ...

# %%
"""
years_by_numb_of_games_values
years_by_numb_of_games_counts
top_osales_inyears[top_osales_inyears["Year"] == 2011]
"""
game09 = games[games.Year == 2009]
other_val = top_osales_inyears.Publisher[top_osales_inyears.Year == 2009]
values = pd.DataFrame()
result = pd.DataFrame()
for i in range(len(other_val)):
    if i == 0:
        values = game09[game09.Publisher == other_val.iloc[i]]
        result = values[values.Other_Sales == values.Other_Sales.max()]
    else:
        values = game09[game09.Publisher == other_val.iloc[i]]
        result = result.append(values[values.Other_Sales == values.Other_Sales.max()])


fig = px.sunburst(result, path = ["Name", "Genre", "Publisher"], values = result["Other_Sales"],
                      title="Best Selling Games of the Top 5 Publishers in Other Regions in 2009 and Their Genres")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="5ab503ff-3545-4d95-9bb4-a5f0c0164edb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ab503ff-3545-4d95-9bb4-a5f0c0164edb")) {                    Plotly.newPlot(                        "5ab503ff-3545-4d95-9bb4-a5f0c0164edb",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Other_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Call of Duty: Modern Warfare 2/Shooter/Activision", "FIFA Soccer 10/Sports/Electronic Arts", "Wii Sports Resort/Sports/Nintendo", "Uncharted 2: Among Thieves/Action/Sony Computer Entertainment", "Assassin's Creed II/Action/Ubisoft", "Assassin's Creed II/Action", "Uncharted 2: Among Thieves/Action", "Call of Duty: Modern Warfare 2/Shooter", "FIFA Soccer 10/Sports", "Wii Sports Resort/Sports", "Assassin's Creed II", "Call of Duty: Modern Warfare 2", "FIFA Soccer 10", "Uncharted 2: Among Thieves", "Wii Sports Resort"], "labels": ["Activision", "Electronic Arts", "Nintendo", "Sony Computer Entertainment", "Ubisoft", "Action", "Action", "Shooter", "Sports", "Sports", "Assassin's Creed II", "Call of Duty: Modern Warfare 2", "FIFA Soccer 10", "Uncharted 2: Among Thieves", "Wii Sports Resort"], "name": "", "parents": ["Call of Duty: Modern Warfare 2/Shooter", "FIFA Soccer 10/Sports", "Wii Sports Resort/Sports", "Uncharted 2: Among Thieves/Action", "Assassin's Creed II/Action", "Assassin's Creed II", "Uncharted 2: Among Thieves", "Call of Duty: Modern Warfare 2", "FIFA Soccer 10", "Wii Sports Resort", "", "", "", "", ""], "type": "sunburst", "values": [1.63, 1.23, 2.96, 1.0, 0.87, 0.87, 1.0, 1.63, 1.23, 2.96, 0.87, 1.63, 1.23, 1.0, 2.96]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca2 ...

# %%
#global sales according to years - zoom toplantısında yapılan kısım
#group by genre and year
figs = []
game_sales_inyears = games.groupby(['Year','Genre'], as_index=False)['Global_Sales'].sum()
top_genre_sales_inyears = pd.DataFrame()

for i in range(len(years)):
    if i == 0:
        top_genre_sales_inyears = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "Global_Sales",
                                                                                                   ascending = False).head(5)
        
    else:
        df = game_sales_inyears[game_sales_inyears["Year"] == years[i]].sort_values(by = "Global_Sales",
                                                                                    ascending = False).head(5)
        top_genre_sales_inyears = top_genre_sales_inyears.append(df, ignore_index=True)

top_genre_sales_inyears
# Out:
#        Year         Genre  Global_Sales
# 0    1980.0       Shooter          7.07
# 1    1980.0          Misc          2.71
# 2    1980.0      Fighting          0.77
# 3    1980.0        Sports          0.49
# 4    1980.0        Action          0.34
# ..      ...           ...           ...
# 183  2016.0  Role-Playing          6.76
# 184  2016.0      Fighting          3.86
# 185  2017.0  Role-Playing          0.04
# 186  2017.0        Action          0.01
# 187  2020.0    Simulation          0.29
#
# [188 rows x 3 columns]

# %%
publishers = top_genre_sales_inyears.Genre.unique()
for p in range(len(publishers)):
    figs.append(go.Scatter(x = years, y=top_genre_sales_inyears.Global_Sales[top_genre_sales_inyears.Genre == publishers[p]],
                           name=publishers[p], line_shape="vh"))
     
    
layout = dict(title="Year Wise Global Game Sales According to Years",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="e2699095-49e2-4e37-b9d1-a29b7bf24a9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2699095-49e2-4e37-b9d1-a29b7bf24a9e")) {                    Plotly.newPlot(                        "e2699095-49e2-4e37-b9d1-a29b7bf24a9e",                        [{"line": {"shape": "vh"}, "name": "Shooter", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [7.069999999999999, 10.040000000000001, 3.79, 31.099999999999998, 3.89, 8.3, 22.169999999999998, 24.770000000000003, 48.579999999999984, 71.03999999999999, 69.89000000000001, 77.40999999999994, 99.36, 72.85999999999999, 62.799999999999976, 65.99999999999996, 66.14999999999999, 18.219999999999995]}, {"line": {"shape": "vh"}, "name": "Misc", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [2.71, 2.14, 59.81, 67.34999999999995, 91.06, 87.03000000000004, 76.94000000000001, 96.86000000000001, 56.08, 22.920000000000012, 25.65, 23.68000000000001, 11.689999999999998]}, {"line": {"shape": "vh"}, "name": "Fighting", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [0.77, 1.05, 5.42, 15.25, 8.750000000000002, 8.47, 14.85, 18.06000000000001, 31.660000000000018, 20.22, 3.859999999999999]}, {"line": {"shape": "vh"}, "name": "Sports", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [0.49, 0.7899999999999999, 3.2, 6.18, 1.96, 5.57, 3.7199999999999998, 3.5999999999999996, 5.720000000000001, 2.4099999999999997, 3.1799999999999997, 8.389999999999999, 7.980000000000002, 30.020000000000003, 41.79000000000002, 30.289999999999996, 41.19, 51.43000000000002, 65.41999999999999, 56.11, 63.68000000000003, 59.540000000000035, 136.16000000000003, 98.20000000000002, 95.33999999999996, 138.5200000000001, 92.53, 56.990000000000016, 30.930000000000007, 41.550000000000026, 46.66, 41.54000000000001, 14.599999999999996]}, {"line": {"shape": "vh"}, "name": "Action", "type": "scatter", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [0.34, 14.84, 6.52, 2.86, 1.85, 3.52, 13.740000000000002, 4.64, 6.390000000000001, 6.76, 20.580000000000005, 27.580000000000002, 39.440000000000005, 27.77999999999999, 34.04000000000002, 59.39000000000001, 86.76999999999992, 67.92999999999999, 76.25999999999998, 85.69000000000005, 66.58, 106.50000000000006, 136.39, 139.3600000000001, 117.63999999999997, 118.96000000000001, 122.00999999999988, 125.2 ...

0.00      0.01      0.00
#
#        Other_Sales  Global_Sales
# 16            4.14         21.40
# 17           10.57         20.81
# 23            1.38         16.38
# 24            1.78         16.15
# 38            1.30         13.10
# 44            2.02         11.98
# 51            1.03         11.02
# 56            1.62         10.57
# 90            1.75          7.72
# 197           0.41          5.08
# 198           1.21          5.08
# 360           0.50          3.54
# 388           0.22          3.42
# 684           0.14          2.32
# 873           0.09          1.95
# 1441          0.14          1.35
# 1896          0.08          1.08
# 1902          0.28          1.08
# 2120          0.05          0.98
# 2138          0.13          0.97
# 2357          0.08          0.88
# 6905          0.00          0.24
# 9827          0.01          0.12
# 10379         0.01          0.11
# 13732         0.01          0.04
# 16093         0.00          0.01

# %%
figs = []
gta_sales_inyears = GTA.groupby(['Name','Year'], as_index=False)['Global_Sales'].sum()

names = GTA.Name.unique()

for n in range(len(names)):
    figs.append(go.Scatter(x = gta_sales_inyears.Year[gta_sales_inyears.Name == names[n]],
                           y=gta_sales_inyears.Global_Sales[gta_sales_inyears.Name == names[n]],
                           name=names[n], line_shape="vh"))
     
    
layout = dict(title="Year Wise Grand Theft Auto Series",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="e21a11c8-0b52-4c1a-9537-19340658acab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e21a11c8-0b52-4c1a-9537-19340658acab")) {                    Plotly.newPlot(                        "e21a11c8-0b52-4c1a-9537-19340658acab",                        [{"line": {"shape": "vh"}, "name": "Grand Theft Auto V", "type": "scatter", "x": [2013.0, 2014.0, 2015.0], "y": [37.78, 17.060000000000002, 1.08]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto: San Andreas", "type": "scatter", "x": [2004.0, 2005.0, 2008.0], "y": [20.81, 2.9299999999999997, 0.12]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto: Vice City", "type": "scatter", "x": [2002.0, 2003.0], "y": [16.15, 0.04]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto III", "type": "scatter", "x": [2001.0, 2002.0], "y": [13.1, 0.01]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto IV", "type": "scatter", "x": [2008.0], "y": [22.47]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto: Liberty City Stories", "type": "scatter", "x": [2005.0, 2006.0], "y": [7.72, 3.54]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto: Vice City Stories", "type": "scatter", "x": [2006.0, 2007.0], "y": [5.08, 0.97]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto 2", "type": "scatter", "x": [1998.0], "y": [3.42]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto", "type": "scatter", "x": [1997.0, 2004.0], "y": [2.32, 0.24]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto: Chinatown Wars", "type": "scatter", "x": [2009.0], "y": [2.43]}, {"line": {"shape": "vh"}, "name": "Grand Theft Auto: Mission Pack #1, London 1969", "type": "scatter", "x": [1998.0], "y": [0.11]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histo ...

# %%
fig = px.scatter(gta_sales_inyears, x="Global_Sales", y="Year", color="Name", size="Global_Sales",
                hover_data=["Name"], title="Year Wise Grand Theft Auto (GTA) Series",
                labels={"x": "Global_Sales", "y": "Year"})
fig.show()
# Out:
# <div>                            <div id="0a9e67fe-6f97-469e-b599-aca56ae85213" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a9e67fe-6f97-469e-b599-aca56ae85213")) {                    Plotly.newPlot(                        "0a9e67fe-6f97-469e-b599-aca56ae85213",                        [{"customdata": [["Grand Theft Auto"], ["Grand Theft Auto"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Grand Theft Auto", "marker": {"color": "#636efa", "size": [2.32, 0.24], "sizemode": "area", "sizeref": 0.09445, "symbol": "circle"}, "mode": "markers", "name": "Grand Theft Auto", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2.32, 0.24], "xaxis": "x", "y": [1997.0, 2004.0], "yaxis": "y"}, {"customdata": [["Grand Theft Auto 2"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Grand Theft Auto 2", "marker": {"color": "#EF553B", "size": [3.42], "sizemode": "area", "sizeref": 0.09445, "symbol": "circle"}, "mode": "markers", "name": "Grand Theft Auto 2", "orientation": "v", "showlegend": true, "type": "scatter", "x": [3.42], "xaxis": "x", "y": [1998.0], "yaxis": "y"}, {"customdata": [["Grand Theft Auto III"], ["Grand Theft Auto III"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Grand Theft Auto III", "marker": {"color": "#00cc96", "size": [13.1, 0.01], "sizemode": "area", "sizeref": 0.09445, "symbol": "circle"}, "mode": "markers", "name": "Grand Theft Auto III", "orientation": "v", "showlegend": true, "type": "scatter", "x": [13.1, 0.01], "xaxis": "x", "y": [2001.0, 2002.0], "yaxis": "y"}, {"customdata": [["Grand Theft Auto IV"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Grand Theft Auto IV", "marker": {"color": "#ab63fa", "size": [22.47], "sizemode": "area", "sizeref": 0.09445, "symbol": "circle"}, "mode": "markers", "name": "Grand Theft Auto IV", "orientation": "v", "showlegend": true, "type": "scatter", "x": [22.47], "xaxis": "x", "y": [2008.0], "yaxis": "y"}, {"customdata": [["Grand Theft Auto V"], ["Grand Theft Auto V"], ["Grand Theft Auto V"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Grand Theft Auto V", "marker": {"color": "#FFA15A", "size": [37.78, 17.060000000000002, 1.08], "sizemode": "area", "sizeref": 0.09445, "symbol": "circle"}, "mode": "markers", "name": "Grand Theft Auto V", "orientation": "v", "showlegend": true, "type": "scatter", "x": [37.78, 17.060000000000002, 1.08], "xaxis": "x", "y": [2013.0, 2014.0, 2015.0], "yaxis": "y"}, {"customdata": [["Grand Theft Auto: Chinatown Wars"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Grand Theft Auto: Chinatown Wars", "marker": {"color": "#19d3f3", "size": [2.43], "sizemode": "area", "sizeref": 0.09445, "symbol": "circle"}, "mode": "markers", "name": "Grand Theft Auto: Chinatown Wars", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2.43], "xaxis": "x", "y": [2009.0], "yaxis": "y"}, {"customdata": [["Grand Theft Auto: Liberty City Stories"], ["Grand Theft Auto: Liberty City Stories"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Grand Theft Auto: Liberty City Stories", "marker": {"color": "#FF6692", "size": [7.72, 3.54], "sizemode": "area", "sizeref": 0.09445, "symbol": "circle"}, "mode": "markers", "name": "Grand Theft Auto: Liberty City Stories", "orientation": "v", "showlegend": true, "type": "scatter", ...

# %%
fig = px.sunburst(GTA, path = ["Publisher", "Genre", "Name"], values = GTA["Global_Sales"],
                      title="Grand Theft Auto (GTA) Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="8cfb41d2-783f-467f-a43d-b17e3383a1cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cfb41d2-783f-467f-a43d-b17e3383a1cd")) {                    Plotly.newPlot(                        "8cfb41d2-783f-467f-a43d-b17e3383a1cd",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Take-Two Interactive/Action/Grand Theft Auto", "Take-Two Interactive/Action/Grand Theft Auto 2", "Take-Two Interactive/Action/Grand Theft Auto III", "Take-Two Interactive/Action/Grand Theft Auto IV", "Take-Two Interactive/Action/Grand Theft Auto V", "Take-Two Interactive/Action/Grand Theft Auto: Chinatown Wars", "Take-Two Interactive/Action/Grand Theft Auto: Liberty City Stories", "Take-Two Interactive/Adventure/Grand Theft Auto: Mission Pack #1, London 1969", "Take-Two Interactive/Action/Grand Theft Auto: San Andreas", "Take-Two Interactive/Action/Grand Theft Auto: Vice City", "Take-Two Interactive/Action/Grand Theft Auto: Vice City Stories", "Take-Two Interactive/Action", "Take-Two Interactive/Adventure", "Take-Two Interactive"], "labels": ["Grand Theft Auto", "Grand Theft Auto 2", "Grand Theft Auto III", "Grand Theft Auto IV", "Grand Theft Auto V", "Grand Theft Auto: Chinatown Wars", "Grand Theft Auto: Liberty City Stories", "Grand Theft Auto: Mission Pack #1, London 1969", "Grand Theft Auto: San Andreas", "Grand Theft Auto: Vice City", "Grand Theft Auto: Vice City Stories", "Action", "Adventure", "Take-Two Interactive"], "name": "", "parents": ["Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive/Adventure", "Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive", "Take-Two Interactive", ""], "type": "sunburst", "values": [2.5599999999999996, 3.42, 13.11, 22.47, 55.92, 2.43, 11.26, 0.11, 23.86, 16.189999999999998, 6.05, 157.26999999999995, 0.11, 157.37999999999997]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"],  ...

# %%
Driver = games[games["Name"].str.match("Driver") == True]
Driver
# Out:
#         Rank                    Name Platform    Year   Genre  \
# 138      139                  Driver       PS  1999.0  Action
# 223      224                Driver 2       PS  2000.0  Action
# 2117    2119   Driver: San Francisco      PS3  2011.0  Racing
# 2848    2850   Driver: San Francisco     X360  2011.0  Racing
# 5367    5369        Driver 2 Advance      GBA  2002.0  Action
# 6180    6182  Driver: Parallel Lines      PS2  2006.0  Racing
# 6761    6763              Driver '76      PSP  2007.0  Racing
# 8056    8058   Driver: San Francisco       PC  2011.0  Racing
# 8176    8178   Driver: San Francisco      Wii  2011.0  Racing
# 10981  10983        Driver: Renegade      3DS  2011.0  Racing
# 12154  12156  Driver: Parallel Lines       XB  2006.0  Racing
# 12833  12835     Drivers Ed Portable       DS  2008.0    Misc
# 14598  14601  Driver: Parallel Lines      Wii  2007.0  Racing
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 138        GT Interactive      3.11      2.80      0.02         0.33
# 223                 Atari      2.36      2.10      0.02         0.25
# 2117              Ubisoft      0.24      0.54      0.01         0.18
# 2848              Ubisoft      0.25      0.39      0.00         0.08
# 5367                Atari      0.25      0.09      0.00         0.01
# 6180                Atari      0.12      0.10      0.03         0.03
# 6761              Ubisoft      0.03      0.14      0.00         0.08
# 8056              Ubisoft      0.05      0.10      0.00         0.03
# 8176              Ubisoft      0.06      0.09      0.00         0.02
# 10981             Ubisoft      0.05      0.04      0.00         0.01
# 12154               Atari      0.05      0.01      0.00         0.00
# 12833  JoWood Productions      0.05      0.00      0.00         0.00
# 14598             Ubisoft      0.01      0.01      0.00         0.00
#
#        Global_Sales
# 138            6.27
# 223            4.73
# 2117           0.98
# 2848           0.72
# 5367           0.34
# 6180           0.28
# 6761           0.25
# 8056           0.18
# 8176           0.18
# 10981          0.09
# 12154          0.07
# 12833          0.05
# 14598          0.03

# %%
WatchDogs = games[games["Name"].str.match("Watch Dogs") == True]
WatchDogs
# Out:
#       Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 280    281  Watch Dogs      PS4  2014.0  Action   Ubisoft      1.40      1.86
# 891    893  Watch Dogs      PS3  2014.0  Action   Ubisoft      0.56      0.89
# 1202  1204  Watch Dogs     XOne  2014.0  Action   Ubisoft      0.90      0.53
# 1539  1541  Watch Dogs     X360  2014.0  Action   Ubisoft      0.72      0.45
# 4333  4335  Watch Dogs       PC  2014.0  Action   Ubisoft      0.14      0.26
# 9112  9114  Watch Dogs     WiiU  2014.0  Action   Ubisoft      0.08      0.05
#
#       JP_Sales  Other_Sales  Global_Sales
# 280       0.11         0.77          4.14
# 891       0.10         0.37          1.93
# 1202      0.00         0.13          1.55
# 1539      0.01         0.11          1.28
# 4333      0.00         0.05          0.45
# 9112      0.00         0.01          0.14

# %%
#Cobine this two dataframe / Driver + Watchdogs
frames = [Driver, WatchDogs]
Driver_and_WatchDogs = pd.concat(frames)

# %%
figs = []
driver_sales_inyears = Driver_and_WatchDogs.groupby(['Name','Year'], as_index=False)['Global_Sales'].sum()

names = Driver_and_WatchDogs.Name.unique()

for n in range(len(names)):
    figs.append(go.Scatter(x = driver_sales_inyears.Year[driver_sales_inyears.Name == names[n]],
                           y=driver_sales_inyears.Global_Sales[driver_sales_inyears.Name == names[n]],
                           name=names[n], line_shape="vh"))
     
    
layout = dict(title="Year Wise Driver and Watch Dogs Series",
             xaxis = dict(title = "Years"), yaxis=dict(title = "Total Sales In Millions"))
figure=dict(data=figs, layout=layout)
iplot(figure)
# Out:
# <div>                            <div id="573e53d7-ba5d-464b-a0f6-6b6f0a3b9685" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("573e53d7-ba5d-464b-a0f6-6b6f0a3b9685")) {                    Plotly.newPlot(                        "573e53d7-ba5d-464b-a0f6-6b6f0a3b9685",                        [{"line": {"shape": "vh"}, "name": "Driver", "type": "scatter", "x": [1999.0], "y": [6.27]}, {"line": {"shape": "vh"}, "name": "Driver 2", "type": "scatter", "x": [2000.0], "y": [4.73]}, {"line": {"shape": "vh"}, "name": "Driver: San Francisco", "type": "scatter", "x": [2011.0], "y": [2.06]}, {"line": {"shape": "vh"}, "name": "Driver 2 Advance", "type": "scatter", "x": [2002.0], "y": [0.34]}, {"line": {"shape": "vh"}, "name": "Driver: Parallel Lines", "type": "scatter", "x": [2006.0, 2007.0], "y": [0.35000000000000003, 0.03]}, {"line": {"shape": "vh"}, "name": "Driver '76", "type": "scatter", "x": [2007.0], "y": [0.25]}, {"line": {"shape": "vh"}, "name": "Driver: Renegade", "type": "scatter", "x": [2011.0], "y": [0.09]}, {"line": {"shape": "vh"}, "name": "Drivers Ed Portable", "type": "scatter", "x": [2008.0], "y": [0.05]}, {"line": {"shape": "vh"}, "name": "Watch Dogs", "type": "scatter", "x": [2014.0], "y": [9.489999999999998]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tic ...

# %%
fig = px.scatter(driver_sales_inyears, x="Global_Sales", y="Year", color="Name", size="Global_Sales",
                hover_data=["Name"], title="Year Wise Driver and Watch Dogs Series",
                labels={"x": "Global_Sales", "y": "Year"})
fig.show()
# Out:
# <div>                            <div id="5eb5b5a6-9cb2-4fe3-b62e-bfe1b17389d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5eb5b5a6-9cb2-4fe3-b62e-bfe1b17389d2")) {                    Plotly.newPlot(                        "5eb5b5a6-9cb2-4fe3-b62e-bfe1b17389d2",                        [{"customdata": [["Driver"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Driver", "marker": {"color": "#636efa", "size": [6.27], "sizemode": "area", "sizeref": 0.023724999999999996, "symbol": "circle"}, "mode": "markers", "name": "Driver", "orientation": "v", "showlegend": true, "type": "scatter", "x": [6.27], "xaxis": "x", "y": [1999.0], "yaxis": "y"}, {"customdata": [["Driver '76"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Driver '76", "marker": {"color": "#EF553B", "size": [0.25], "sizemode": "area", "sizeref": 0.023724999999999996, "symbol": "circle"}, "mode": "markers", "name": "Driver '76", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.25], "xaxis": "x", "y": [2007.0], "yaxis": "y"}, {"customdata": [["Driver 2"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Driver 2", "marker": {"color": "#00cc96", "size": [4.73], "sizemode": "area", "sizeref": 0.023724999999999996, "symbol": "circle"}, "mode": "markers", "name": "Driver 2", "orientation": "v", "showlegend": true, "type": "scatter", "x": [4.73], "xaxis": "x", "y": [2000.0], "yaxis": "y"}, {"customdata": [["Driver 2 Advance"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Driver 2 Advance", "marker": {"color": "#ab63fa", "size": [0.34], "sizemode": "area", "sizeref": 0.023724999999999996, "symbol": "circle"}, "mode": "markers", "name": "Driver 2 Advance", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.34], "xaxis": "x", "y": [2002.0], "yaxis": "y"}, {"customdata": [["Driver: Parallel Lines"], ["Driver: Parallel Lines"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Driver: Parallel Lines", "marker": {"color": "#FFA15A", "size": [0.35000000000000003, 0.03], "sizemode": "area", "sizeref": 0.023724999999999996, "symbol": "circle"}, "mode": "markers", "name": "Driver: Parallel Lines", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.35000000000000003, 0.03], "xaxis": "x", "y": [2006.0, 2007.0], "yaxis": "y"}, {"customdata": [["Driver: Renegade"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Driver: Renegade", "marker": {"color": "#19d3f3", "size": [0.09], "sizemode": "area", "sizeref": 0.023724999999999996, "symbol": "circle"}, "mode": "markers", "name": "Driver: Renegade", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.09], "xaxis": "x", "y": [2011.0], "yaxis": "y"}, {"customdata": [["Driver: San Francisco"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Driver: San Francisco", "marker": {"color": "#FF6692", "size": [2.06], "sizemode": "area", "sizeref": 0.023724999999999996, "symbol": "circle"}, "mode": "markers", "name": "Driver: San Francisco", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2.06], "xaxis": "x", "y": [2011.0], "yaxis": "y"}, {"customdata": [["Drivers Ed Portable"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Drivers Ed Portable", "marker": {"color": "#B6E880", "size ...

# %%
fig = px.sunburst(Driver_and_WatchDogs, path = ["Publisher", "Genre", "Name"], values = Driver_and_WatchDogs["Global_Sales"],
                      title="Driver and Watch Dogs Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="0d1b44f1-162c-497f-86a1-f7a4d89e8943" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d1b44f1-162c-497f-86a1-f7a4d89e8943")) {                    Plotly.newPlot(                        "0d1b44f1-162c-497f-86a1-f7a4d89e8943",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["GT Interactive/Action/Driver", "Ubisoft/Racing/Driver '76", "Atari/Action/Driver 2", "Atari/Action/Driver 2 Advance", "Atari/Racing/Driver: Parallel Lines", "Ubisoft/Racing/Driver: Parallel Lines", "Ubisoft/Racing/Driver: Renegade", "Ubisoft/Racing/Driver: San Francisco", "JoWood Productions/Misc/Drivers Ed Portable", "Ubisoft/Action/Watch Dogs", "Atari/Action", "GT Interactive/Action", "Ubisoft/Action", "JoWood Productions/Misc", "Atari/Racing", "Ubisoft/Racing", "Atari", "GT Interactive", "JoWood Productions", "Ubisoft"], "labels": ["Driver", "Driver '76", "Driver 2", "Driver 2 Advance", "Driver: Parallel Lines", "Driver: Parallel Lines", "Driver: Renegade", "Driver: San Francisco", "Drivers Ed Portable", "Watch Dogs", "Action", "Action", "Action", "Misc", "Racing", "Racing", "Atari", "GT Interactive", "JoWood Productions", "Ubisoft"], "name": "", "parents": ["GT Interactive/Action", "Ubisoft/Racing", "Atari/Action", "Atari/Action", "Atari/Racing", "Ubisoft/Racing", "Ubisoft/Racing", "Ubisoft/Racing", "JoWood Productions/Misc", "Ubisoft/Action", "Atari", "GT Interactive", "Ubisoft", "JoWood Productions", "Atari", "Ubisoft", "", "", "", ""], "type": "sunburst", "values": [6.27, 0.25, 4.73, 0.34, 0.35000000000000003, 0.03, 0.09, 2.06, 0.05, 9.489999999999998, 5.07, 6.27, 9.489999999999998, 0.05, 0.35000000000000003, 2.4299999999999997, 5.420000000000001, 6.27, 0.05, 11.92]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.444444444 ...

# %%
figs = []
watchdogs_sales_inyears = WatchDogs.groupby(['Name','Year'], as_index=False)['Global_Sales'].sum()

fig = px.scatter(watchdogs_sales_inyears, x="Global_Sales", y="Year", color="Name", size="Global_Sales",
                hover_data=["Name"], title="Year Wise Watch Dogs Series",
                labels={"x": "Global_Sales", "y": "Year"})
fig.show()
# Out:
# <div>                            <div id="028a53b5-a5d7-42a8-a178-10c5b58d6043" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("028a53b5-a5d7-42a8-a178-10c5b58d6043")) {                    Plotly.newPlot(                        "028a53b5-a5d7-42a8-a178-10c5b58d6043",                        [{"customdata": [["Watch Dogs"]], "hovertemplate": "Name=%{customdata[0]}<br>Global_Sales=%{marker.size}<br>Year=%{y}<extra></extra>", "legendgroup": "Watch Dogs", "marker": {"color": "#636efa", "size": [9.489999999999998], "sizemode": "area", "sizeref": 0.023724999999999996, "symbol": "circle"}, "mode": "markers", "name": "Watch Dogs", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.489999999999998], "xaxis": "x", "y": [2014.0], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "Name"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinew ...

# %%
fig = px.sunburst(WatchDogs, path = ["Publisher", "Genre", "Name", "Platform"], values = WatchDogs["Global_Sales"],
                      title="Watch Dogs Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="55635cfc-efe3-4f61-9352-2333edfa99e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55635cfc-efe3-4f61-9352-2333edfa99e0")) {                    Plotly.newPlot(                        "55635cfc-efe3-4f61-9352-2333edfa99e0",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Ubisoft/Action/Watch Dogs/PC", "Ubisoft/Action/Watch Dogs/PS3", "Ubisoft/Action/Watch Dogs/PS4", "Ubisoft/Action/Watch Dogs/WiiU", "Ubisoft/Action/Watch Dogs/X360", "Ubisoft/Action/Watch Dogs/XOne", "Ubisoft/Action/Watch Dogs", "Ubisoft/Action", "Ubisoft"], "labels": ["PC", "PS3", "PS4", "WiiU", "X360", "XOne", "Watch Dogs", "Action", "Ubisoft"], "name": "", "parents": ["Ubisoft/Action/Watch Dogs", "Ubisoft/Action/Watch Dogs", "Ubisoft/Action/Watch Dogs", "Ubisoft/Action/Watch Dogs", "Ubisoft/Action/Watch Dogs", "Ubisoft/Action/Watch Dogs", "Ubisoft/Action", "Ubisoft", ""], "type": "sunburst", "values": [0.45, 1.93, 4.14, 0.14, 1.28, 1.55, 9.489999999999998, 9.489999999999998, 9.489999999999998]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d" ...

# %%
Uncharted = games[games["Name"].str.match("Uncharted") == True]
Uncharted
# Out:
#       Rank                                    Name Platform    Year    Genre  \
# 115    116          Uncharted 3: Drake's Deception      PS3  2011.0   Action
# 119    120              Uncharted 2: Among Thieves      PS3  2009.0   Action
# 210    211              Uncharted: Drake's Fortune      PS3  2007.0   Action
# 243    244  Uncharted: The Nathan Drake Collection      PS4  2015.0   Action
# 271    272              Uncharted 4: A Thief's End      PS4  2016.0  Shooter
# 1023  1025                 Uncharted: Golden Abyss      PSV  2011.0  Shooter
#
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 115   Sony Computer Entertainment      2.77      2.80      0.19         1.06
# 119   Sony Computer Entertainment      3.27      2.25      0.21         1.00
# 210   Sony Computer Entertainment      2.31      1.73      0.12         0.78
# 243   Sony Computer Entertainment      1.96      1.69      0.08         0.74
# 271   Sony Computer Entertainment      1.30      2.07      0.18         0.65
# 1023  Sony Computer Entertainment      0.59      0.75      0.13         0.27
#
#       Global_Sales
# 115           6.83
# 119           6.73
# 210           4.94
# 243           4.47
# 271           4.20
# 1023          1.74

# %%
fig = px.sunburst(Uncharted, path = ["Publisher", "Genre", "Name"], values = Uncharted["Global_Sales"],
                      title="Uncharted Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="af0b8b07-1ae1-46be-b974-ac48915a353a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af0b8b07-1ae1-46be-b974-ac48915a353a")) {                    Plotly.newPlot(                        "af0b8b07-1ae1-46be-b974-ac48915a353a",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Sony Computer Entertainment/Action/Uncharted 2: Among Thieves", "Sony Computer Entertainment/Action/Uncharted 3: Drake's Deception", "Sony Computer Entertainment/Shooter/Uncharted 4: A Thief's End", "Sony Computer Entertainment/Action/Uncharted: Drake's Fortune", "Sony Computer Entertainment/Shooter/Uncharted: Golden Abyss", "Sony Computer Entertainment/Action/Uncharted: The Nathan Drake Collection", "Sony Computer Entertainment/Action", "Sony Computer Entertainment/Shooter", "Sony Computer Entertainment"], "labels": ["Uncharted 2: Among Thieves", "Uncharted 3: Drake's Deception", "Uncharted 4: A Thief's End", "Uncharted: Drake's Fortune", "Uncharted: Golden Abyss", "Uncharted: The Nathan Drake Collection", "Action", "Shooter", "Sony Computer Entertainment"], "name": "", "parents": ["Sony Computer Entertainment/Action", "Sony Computer Entertainment/Action", "Sony Computer Entertainment/Shooter", "Sony Computer Entertainment/Action", "Sony Computer Entertainment/Shooter", "Sony Computer Entertainment/Action", "Sony Computer Entertainment", "Sony Computer Entertainment", ""], "type": "sunburst", "values": [6.73, 6.83, 4.2, 4.94, 1.74, 4.47, 22.97, 5.94, 28.909999999999997]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram" ...

# %%
RDR = games[games["Name"].str.match("Red Dead Redemption") == True]
RDR
# Out:
#       Rank                                   Name Platform    Year   Genre  \
# 123    124                    Red Dead Redemption      PS3  2010.0  Action
# 134    135                    Red Dead Redemption     X360  2010.0  Action
# 1767  1769  Red Dead Redemption: Undead Nightmare      PS3  2010.0  Action
# 1921  1923  Red Dead Redemption: Undead Nightmare     X360  2010.0  Action
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 123   Take-Two Interactive      2.79      2.61      0.17         1.03
# 134   Take-Two Interactive      3.70      1.97      0.09         0.57
# 1767  Take-Two Interactive      0.44      0.46      0.06         0.18
# 1921  Take-Two Interactive      0.57      0.39      0.02         0.09
#
#       Global_Sales
# 123           6.60
# 134           6.34
# 1767          1.15
# 1921          1.07

# %%
fig = px.sunburst(RDR, path = ["Publisher", "Genre", "Name"], values = RDR["Global_Sales"],
                      title="Red Dead Redemption (RDR) Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="37aac47d-3725-4647-ab38-930a5ab3a33f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37aac47d-3725-4647-ab38-930a5ab3a33f")) {                    Plotly.newPlot(                        "37aac47d-3725-4647-ab38-930a5ab3a33f",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Take-Two Interactive/Action/Red Dead Redemption", "Take-Two Interactive/Action/Red Dead Redemption: Undead Nightmare", "Take-Two Interactive/Action", "Take-Two Interactive"], "labels": ["Red Dead Redemption", "Red Dead Redemption: Undead Nightmare", "Action", "Take-Two Interactive"], "name": "", "parents": ["Take-Two Interactive/Action", "Take-Two Interactive/Action", "Take-Two Interactive", ""], "type": "sunburst", "values": [12.94, 2.2199999999999998, 15.16, 15.16]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd37 ...

# %%
FIFA = games[games["Name"].str.match("FIFA") == True]
FIFA
# Out:
#         Rank                                Name Platform    Year   Genre  \
# 77        78                             FIFA 16      PS4  2015.0  Sports
# 82        83                      FIFA Soccer 13      PS3  2012.0  Action
# 112      113                             FIFA 14      PS3  2013.0  Sports
# 121      122                             FIFA 12      PS3  2011.0  Sports
# 124      125                             FIFA 15      PS4  2014.0  Sports
# ...      ...                                 ...      ...     ...     ...
# 13611  13613  FIFA Soccer 2003 (weekly jp sales)      PS2  2002.0  Sports
# 13851  13853         FIFA World Cup Germany 2006       DS  2006.0  Sports
# 14251  14254        FIFA World Cup: Germany 2006      GBA  2006.0  Sports
# 15205  15208                      FIFA Soccer 09       PC  2008.0  Sports
# 15837  15840                      FIFA Soccer 08       PC  2007.0  Sports
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 77     Electronic Arts      1.11      6.06      0.06         1.26
# 82     Electronic Arts      1.06      5.05      0.13         2.01
# 112    Electronic Arts      0.78      4.32      0.07         1.73
# 121    Electronic Arts      0.84      4.32      0.11         1.42
# 124    Electronic Arts      0.79      4.29      0.05         1.47
# ...                ...       ...       ...       ...          ...
# 13611  Electronic Arts      0.00      0.00      0.04         0.00
# 13851  Electronic Arts      0.03      0.00      0.00         0.00
# 14251  Electronic Arts      0.02      0.01      0.00         0.00
# 15205  Electronic Arts      0.00      0.02      0.00         0.00
# 15837  Electronic Arts      0.00      0.01      0.00         0.00
#
#        Global_Sales
# 77             8.49
# 82             8.24
# 112            6.90
# 121            6.69
# 124            6.59
# ...             ...
# 13611          0.04
# 13851          0.04
# 14251          0.03
# 15205          0.02
# 15837          0.02
#
# [131 rows x 11 columns]

# %%
fig = px.sunburst(FIFA, path = ["Publisher", "Genre", "Name"], values = FIFA["Global_Sales"],
                      title="FIFA Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id
electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Action", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", "Electronic Arts/Sports", ...

# %%
PES = games[games["Name"].str.match("PES") == True]
PES
# Out:
#       Rank                            Name Platform    Year   Genre  \
# 614    615  PES 2009: Pro Evolution Soccer      PS2  2008.0  Sports
# 779    781  PES 2009: Pro Evolution Soccer      PS3  2008.0  Sports
# 2057  2059  PES 2009: Pro Evolution Soccer     X360  2008.0  Sports
# 4355  4357  PES 2009: Pro Evolution Soccer      Wii  2009.0  Sports
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 614   Konami Digital Entertainment      0.13      0.07      0.26         2.05
# 779   Konami Digital Entertainment      0.11      1.34      0.40         0.26
# 2057  Konami Digital Entertainment      0.13      0.76      0.03         0.09
# 4355  Konami Digital Entertainment      0.09      0.26      0.05         0.05
#
#       Global_Sales
# 614           2.50
# 779           2.11
# 2057          1.00
# 4355          0.45

# %%
fig = px.sunburst(PES, path = ["Publisher", "Genre", "Name"], values = PES["Global_Sales"],
                      title="PES Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="2ea96f6d-16d5-4a12-89e1-f6077a154168" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ea96f6d-16d5-4a12-89e1-f6077a154168")) {                    Plotly.newPlot(                        "2ea96f6d-16d5-4a12-89e1-f6077a154168",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Konami Digital Entertainment/Sports/PES 2009: Pro Evolution Soccer", "Konami Digital Entertainment/Sports", "Konami Digital Entertainment"], "labels": ["PES 2009: Pro Evolution Soccer", "Sports", "Konami Digital Entertainment"], "name": "", "parents": ["Konami Digital Entertainment/Sports", "Konami Digital Entertainment", ""], "type": "sunburst", "values": [6.06, 6.06, 6.06]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, " ...

# %%
#ancestor of Assassin's Creed
Prince = games[games["Name"].str.match("Prince of Persia") == True]
Prince
# Out:
#         Rank                                   Name Platform    Year  \
# 726      728    Prince of Persia: The Sands of Time      PS2  2003.0
# 1120    1122       Prince of Persia: Warrior Within      PS2  2004.0
# 1894    1896                       Prince of Persia      PS3  2008.0
# 2042    2044                       Prince of Persia     X360  2008.0
# 2214    2216    Prince of Persia: The Sands of Time       XB  2003.0
# 2580    2582       Prince of Persia: Warrior Within       XB  2004.0
# 2921    2923  Prince of Persia: The Forgotten Sands      PS3  2010.0
# 2985    2987      Prince of Persia: The Two Thrones      PS2  2005.0
# 3241    3243  Prince of Persia: The Forgotten Sands     X360  2010.0
# 3472    3474      Prince of Persia: The Two Thrones       XB  2005.0
# 3884    3886               Prince of Persia Trilogy      PS3  2010.0
# 5111    5113  Prince of Persia: The Forgotten Sands      PSP  2010.0
# 5628    5630    Prince of Persia: The Sands of Time       GC  2003.0
# 5982    5984         Prince of Persia: Rival Swords      Wii  2007.0
# 6725    6727  Prince of Persia: The Forgotten Sands      Wii  2010.0
# 7395    7397          Prince of Persia: Revelations      PSP  2005.0
# 7716    7718       Prince of Persia: Warrior Within       GC  2004.0
# 8714    8716  Prince of Persia: The Forgotten Sands       DS  2010.0
# 8812    8814    Prince of Persia: The Sands of Time      GBA  2003.0
# 8921    8923      Prince of Persia: The Two Thrones       GC  2005.0
# 9835    9837         Prince of Persia: Rival Swords      PSP  2007.0
# 12159  12161      Prince of Persia: The Fallen King       DS  2008.0
# 14238  14241  Prince of Persia: The Forgotten Sands       PC  2010.0
# 14695  14698                Prince of Persia (2008)       PC  2008.0
#
#            Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 726       Action   Ubisoft      0.88      1.03      0.00         0.31
# 1120      Action   Ubisoft      0.54      0.88      0.00         0.22
# 1894      Action   Ubisoft      0.47      0.41      0.03         0.18
# 2042      Action   Ubisoft      0.54      0.35      0.02         0.10
# 2214      Action   Ubisoft      0.57      0.33      0.00         0.04
# 2580      Action   Ubisoft      0.48      0.28      0.00         0.04
# 2921      Action   Ubisoft      0.19      0.36      0.01         0.13
# 2985      Action   Ubisoft      0.57      0.02      0.00         0.09
# 3241      Action   Ubisoft      0.30      0.26      0.00         0.06
# 3472      Action   Ubisoft      0.33      0.22      0.00         0.03
# 3884      Action   Ubisoft      0.17      0.25      0.00         0.09
# 5111      Action   Ubisoft      0.09      0.18      0.01         0.10
# 5628      Action   Ubisoft      0.25      0.06      0.00         0.01
# 5982      Action   Ubisoft      0.24      0.03      0.00         0.02
# 6725      Action   Ubisoft      0.11      0.11      0.00         0.02
# 7395   Adventure   Ubisoft      0.18      0.01      0.00         0.02
# 7716      Action   Ubisoft      0.15      0.04      0.00         0.01
# 8714      Action   Ubisoft      0.14      0.01      0.00         0.01
# 8812      Action   Ubisoft      0.11      0.04      0.00         0.00
# 8921      Action   Ubisoft      0.11      0.03      0.00         0.00
# 9835      Action   Ubisoft      0.08      0.02      0.00         0.02
# 12159     Action   Ubisoft      0.06      0.01      0.00         0.01
# 14238     Action   Ubisoft      0.00      0.03      0.00         0.00
# 14695     Action   Ubisoft      0.00      0.02      0.00         0.00
#
#        Global_Sales
# 726            2.22
# 1120           1.64
# 1894           1.08
# 2042           1.01
# 2214           0.94
# 2580           0.80
# 2921           0.70
# 2985           0.68
# 3241           0.62
# 3472           0.58
# 3884           0.51
# 5111           0.37
# 5628           0.32
# 5982           0.29
# 6725           0.25
# 7395           0.21
# 7716           0.20
# 8714           0.16
# 8812           0.15
# 8921           0.15
# 9835           0.12
# 12159          0.07
# 14238          0.03
# 14695          0.03

# %%
fig = px.sunburst(Prince, path = ["Publisher", "Genre", "Name"], values = Prince["Global_Sales"],
                      title="Prince of Persia Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="14987fc7-522e-40f7-853f-6b32153485e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14987fc7-522e-40f7-853f-6b32153485e3")) {                    Plotly.newPlot(                        "14987fc7-522e-40f7-853f-6b32153485e3",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Ubisoft/Action/Prince of Persia", "Ubisoft/Action/Prince of Persia (2008)", "Ubisoft/Action/Prince of Persia Trilogy", "Ubisoft/Adventure/Prince of Persia: Revelations", "Ubisoft/Action/Prince of Persia: Rival Swords", "Ubisoft/Action/Prince of Persia: The Fallen King", "Ubisoft/Action/Prince of Persia: The Forgotten Sands", "Ubisoft/Action/Prince of Persia: The Sands of Time", "Ubisoft/Action/Prince of
genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 128       Action   Ubisoft      2.64      2.56      0.16         1.14
# 156       Action   Ubisoft      2.54      1.95      0.21         0.87
# 158    Adventure   Ubisoft      3.28      1.65      0.07         0.55
# 172       Action   Ubisoft      3.13      1.71      0.03         0.44
# 176       Action   Ubisoft      3.10      1.56      0.08         0.51
# 218    Adventure   Ubisoft      1.91      2.00      0.09         0.83
# 263       Action   Ubisoft      1.41      2.02      0.10         0.72
# 273       Action   Ubisoft      2.25      1.47      0.04         0.43
# 304       Action   Ubisoft      1.18      1.96      0.08         0.70
# 307       Action   Ubisoft      1.33      1.71      0.13         0.73
# 373       Action   Ubisoft      2.84      0.39      0.03         0.24
# 381       Action   Ubisoft      2.26      0.89      0.00         0.30
# 401       Action   Ubisoft      1.90      1.14      0.01         0.29
# 409       Action   Ubisoft      0.80      1.92      0.06         0.50
# 514       Action   Ubisoft      1.87      0.57      0.11         0.30
# 546       Action   Ubisoft      1.07      1.31      0.06         0.31
# 731       Action   Ubisoft      1.47      0.55      0.00         0.19
# 1286      Action   Ubisoft      0.58      0.55      0.06         0.28
# 1413      Action   Ubisoft      0.46      0.62      0.06         0.23
# 1543      Action   Ubisoft      0.61      0.56      0.00         0.11
# 1603      Action   Ubisoft      0.43      0.48      0.05         0.28
# 1964      Action   Ubisoft      0.58      0.38      0.00         0.09
# 2202      Action   Ubisoft      0.28      0.53      0.00         0.13
# 2260   Adventure   Ubisoft      0.01      0.83      0.00         0.08
# 2712      Action   Ubisoft      0.14      0.48      0.00         0.14
# 2961      Action   Ubisoft      0.22      0.38      0.00         0.10
# 3390      Action   Ubisoft      0.15      0.34      0.00         0.10
# 3526      Action   Ubisoft      0.01      0.45      0.00         0.11
# 3656      Action   Ubisoft      0.17      0.33      0.00         0.05
# 5199      Action   Ubisoft      0.19      0.13      0.00         0.03
# 5973      Action   Ubisoft      0.18      0.09      0.00         0.03
# 6141      Action   Ubisoft      0.15      0.11      0.00         0.03
# 7561      Action   Ubisoft      0.10      0.08      0.00         0.02
# 9900      Action   Ubisoft      0.02      0.06      0.01         0.02
# 11581     Action   Ubisoft      0.01      0.05      0.01         0.01
# 12047     Action   Ubisoft      0.04      0.02      0.00         0.01
# 13153   Platform   Ubisoft      0.03      0.01      0.00         0.00
# 14083     Action   Ubisoft      0.00      0.03      0.00         0.01
# 16448     Action   Ubisoft      0.00      0.01      0.00         0.00
#
#        Global_Sales
# 128            6.50
# 156            5.57
# 158            5.55
# 172            5.30
# 176            5.27
# 218            4.83
# 263            4.24
# 273            4.19
# 304            3.92
# 307            3.89
# 373            3.50
# 381            3.46
# 401            3.34
# 409            3.28
# 514            2.84
# 546            2.74
# 731            2.21
# 1286           1.47
# 1413           1.37
# 1543           1.28
# 1603           1.24
# 1964           1.05
# 2202           0.94
# 2260           0.92
# 2712           0.76
# 2961           0.69
# 3390           0.59
# 3526           0.57
# 3656           0.55
# 5199           0.36
# 5973           0.29
# 6141           0.28
# 7561           0.20
# 9900           0.12
# 11581          0.08
# 12047          0.07
# 13153          0.05
# 14083          0.04
# 16448          0.01

# %%
fig = px.sunburst(AC, path = ["Publisher", "Genre", "Name"], values = AC["Global_Sales"],
                      title="Assassin's Creed Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="4303dfb9-e733-46cd-a65f-caa183b5dca8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4303dfb9-e733-46cd-a65f-caa183b5dca8")) {                    Plotly.newPlot(                        "4303dfb9-e733-46cd-a65f-caa183b5dca8",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Ubisoft/Adventure/Assassin's Creed", "Ubisoft/Action/Assassin's Creed Chronicles", "Ubisoft/Action/Assassin's Creed Chronicles: China", "Ubisoft/Action/Assassin's Creed II", "Ubisoft/Action/Assassin's Creed II: Discovery", "Ubisoft/Action/Assassin's Creed III", "Ubisoft/Action/Assassin's Creed III: Liberation", "Ubisoft/Action/Assassin's Creed IV: Black Flag", "Ubisoft/Action/Assassin's Creed Syndicate", "Ubisoft/Platform/Assassin's Creed: Altair's Chronicles", "Ubisoft/Action/Assassin's Creed: Bloodlines", "Ubisoft/Action/Assassin's Creed: Brotherhood", "Ubisoft/Action/Assassin's Creed: Revelations", "Ubisoft/Action/Assassin's Creed: Rogue", "Ubisoft/Action/Assassin's Creed: Unity", "Ubisoft/Action", "Ubisoft/Adventure", "Ubisoft/Platform", "Ubisoft"], "labels": ["Assassin's Creed", "Assassin's Creed Chronicles", "Assassin's Creed Chronicles: China", "Assassin's Creed II", "Assassin's Creed II: Discovery", "Assassin's Creed III", "Assassin's Creed III: Liberation", "Assassin's Creed IV: Black Flag", "Assassin's Creed Syndicate", "Assassin's Creed: Altair's Chronicles", "Assassin's Creed: Bloodlines", "Assassin's Creed: Brotherhood", "Assassin's Creed: Revelations", "Assassin's Creed: Rogue", "Assassin's Creed: Unity", "Action", "Adventure", "Platform", "Ubisoft"], "name": "", "parents": ["Ubisoft/Adventure", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Platform", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft/Action", "Ubisoft", "Ubisoft", "Ubisoft", ""], "type": "sunburst", "values": [11.299999999999999, 0.21000000000000002, 0.04, 11.41, 0.28, 13.1, 1.47, 13.159999999999998, 4.76, 0.05, 1.24, 6.93, 9.19, 2.4899999999999998, 7.93, 72.21000000000001, 11.299999999999999, 0.05, 83.56]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222222222222222 ...

# %%
Mafia = games[games["Name"].str.match("Mafia") == True]
Mafia
# Out:
#         Rank      Name Platform    Year   Genre             Publisher  \
# 1194    1196  Mafia II     X360  2010.0  Action  Take-Two Interactive
# 1237    1239  Mafia II      PS3  2010.0  Action  Take-Two Interactive
# 2931    2933     Mafia      PS2  2004.0  Action    Illusion Softworks
# 4839    4841  Mafia II       PC  2010.0  Action  Take-Two Interactive
# 7051    7053     Mafia       XB  2004.0  Action  Take-Two Interactive
# 13368  13370     Mafia       PC  2002.0  Action  Take-Two Interactive
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 1194       0.84      0.56      0.00         0.15          1.55
# 1237       0.50      0.72      0.04         0.26          1.52
# 2931       0.34      0.27      0.00         0.09          0.70
# 4839       0.17      0.17      0.00         0.06          0.40
# 7051       0.17      0.05      0.00         0.01          0.23
# 13368      0.00      0.04      0.00         0.01          0.05

# %%
fig = px.sunburst(Mafia, path = ["Publisher", "Genre", "Name"], values = Mafia["Global_Sales"],
                      title="Mafia Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="698f75a2-9fbf-458b-8afc-5a66d55e317f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("698f75a2-9fbf-458b-8afc-5a66d55e317f")) {                    Plotly.newPlot(                        "698f75a2-9fbf-458b-8afc-5a66d55e317f",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Illusion Softworks/Action/Mafia", "Take-Two Interactive/Action/Mafia", "Take-Two Interactive/Action/Mafia II", "Illusion Softworks/Action", "Take-Two Interactive/Action", "Illusion Softworks", "Take-Two Interactive"], "labels": ["Mafia", "Mafia", "Mafia II", "Action", "Action", "Illusion Softworks", "Take-Two Interactive"], "name": "", "parents": ["Illusion Softworks/Action", "Take-Two Interactive/Action", "Take-Two Interactive/Action", "Illusion Softworks", "Take-Two Interactive", "", ""], "type": "sunburst", "values": [0.7, 0.28, 3.47, 0.7, 3.75, 0.7, 3.75]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], ...

# %%
#ancestor of call of duty
MedalOfHonor = games[games["Name"].str.match("Medal of Honor") == True]
MedalOfHonor
# Out:
#         Rank                                               Name Platform  \
# 114      115                          Medal of Honor: Frontline      PS2
# 190      191                         Medal of Honor: Rising Sun      PS2
# 517      518                                     Medal of Honor      PS3
# 567      568                                     Medal of Honor       PS
# 572      573                              Medal of Honor Heroes      PSP
# 582      583                                     Medal of Honor     X360
# 916      918  Medal of Honor: European Assault (All Region s...      PS2
# 1268    1270                          Medal of Honor: Frontline       XB
# 1311    1313                         Medal of Honor: Warfighter      PS3
# 1619    1621                           Medal of Honor: Airborne      PS3
# 1725    1727                         Medal of Honor: Warfighter     X360
# 1733    1735                         Medal of Honor: Rising Sun       XB
# 1755    1757                            Medal of Honor Heroes 2      PSP
# 1849    1851                           Medal of Honor: Airborne     X360
# 2147    2149                        Medal of Honor: Underground       PS
# 3393    3395                          Medal of Honor: Frontline       GC
# 3788    3790                   Medal of Honor: European Assault       XB
# 4048    4050                                     Medal of Honor       PC
# 4578    4580                         Medal of Honor: Rising Sun       GC
# 4590    4592                            Medal of Honor Heroes 2      Wii
# 5485    5487                         Medal of Honor: Warfighter       PC
# 6664    6666                    Medal of Honor European Assault       GC
# 8953    8955                        Medal of Honor: Infiltrator      GBA
# 10514  10516                           Medal of Honor: Vanguard      Wii
# 11714  11716                        Medal of Honor: Underground      GBA
# 12829  12831                           Medal of Honor: Airborne       PC
# 13102  13104  Medal of Honor: European Assault (weekly JP sa...      PS2
# 14802  14805                           Medal of Honor: Vanguard      PS2
#
#          Year    Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 114    2002.0  Shooter         Electronic Arts      2.93      2.75      0.17
# 190    2003.0  Shooter         Electronic Arts      1.98      2.23      0.13
# 517    2010.0  Shooter         Electronic Arts      1.28      1.05      0.07
# 567    1998.0  Shooter         Electronic Arts      1.44      1.09      0.00
# 572    2006.0  Shooter         Electronic Arts      0.86      1.11      0.01
# 582    2010.0  Shooter         Electronic Arts      1.55      0.81      0.04
# 916    2005.0  Shooter         Electronic Arts      0.89      0.69      0.09
# 1268   2002.0  Shooter         Electronic Arts      1.00      0.43      0.00
# 1300           1.46
# 1386           1.40
# 1443           1.35
# 1672           1.20
# 2856           0.71
# 3581           0.56
# 4077           0.49
# 4433           0.44
# 4746           0.41
# 5435           0.34
# 9304           0.14
# 11288          0.08
# 14586          0.03
# 14655          0.03
# 14783          0.03
# 14872          0.03
# 14936          0.02

# %%
fig = px.sunburst(Battlefield, path = ["Publisher", "Genre", "Name"], values = Battlefield["Global_Sales"],
                      title="Battlefield Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="c3b830d1-93c1-48d4-9ce1-66c279ec87fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3b830d1-93c1-48d4-9ce1-66c279ec87fb")) {                    Plotly.newPlot(                        "c3b830d1-93c1-48d4-9ce1-66c279ec87fb",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Electronic Arts/Shooter/Battlefield 1942", "Electronic Arts/Shooter/Battlefield 1942: The WW II Anthology", "Electronic Arts/Shooter/Battlefield 2", "Electronic Arts/Shooter/Battlefield 2142", "Electronic Arts/Shooter/Battlefield 2: Modern Combat", "Electronic Arts/Shooter/Battlefield 2: Modern Combat(JP sales)", "Electronic Arts/Shooter/Battlefield 3", "Electronic Arts/Shooter/Battlefield 4", "Electronic Arts/Shooter/Battlefield Vietnam", "Electronic Arts/Shooter/Battlefield: Bad Company", "Electronic Arts/Shooter/Battlefield: Bad Company 2", "Electronic Arts/Shooter/Battlefield: Hardline", "Electronic Arts/Shooter", "Electronic Arts"], "labels": ["Battlefield 1942", "Battlefield 1942: The WW II Anthology", "Battlefield 2", "Battlefield 2142", "Battlefield 2: Modern Combat", "Battlefield 2: Modern Combat(JP sales)", "Battlefield 3", "Battlefield 4", "Battlefield Vietnam", "Battlefield: Bad Company", "Battlefield: Bad Company 2", "Battlefield: Hardline", "Shooter", "Electronic Arts"], "name": "", "parents": ["Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts/Shooter", "Electronic Arts", ""], "type": "sunburst", "values": [0.03, 0.03, 0.08, 0.03, 1.41, 0.02, 17.36, 14.030000000000001, 0.03, 2.81, 7.16, 4.26, 47.25000000000001, 47.25000000000001]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale" ...

# %%
CS = games[games["Name"].str.match("Counter-Strike") == True]
CS
# Out:
#         Rank                    Name Platform    Year    Genre  \
# 1831    1833          Counter-Strike       XB  2003.0  Shooter
# 11195  11197  Counter-Strike: Source       PC  2004.0  Shooter
#
#                     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1831   Microsoft Game Studios      0.85      0.23       0.0         0.04
# 11195           Vivendi Games      0.00      0.07       0.0         0.02
#
#        Global_Sales
# 1831           1.11
# 11195          0.09

# %%
fig = px.sunburst(CS, path = ["Publisher", "Genre", "Name"], values = CS["Global_Sales"],
                      title="Counter Strike (CS) Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="6649e4fb-ef11-40db-9859-c2ab58fb011b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6649e4fb-ef11-40db-9859-c2ab58fb011b")) {                    Plotly.newPlot(                        "6649e4fb-ef11-40db-9859-c2ab58fb011b",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Microsoft Game Studios/Shooter/Counter-Strike", "Vivendi Games/Shooter/Counter-Strike: Source", "Microsoft Game Studios/Shooter", "Vivendi Games/Shooter", "Microsoft Game Studios", "Vivendi Games"], "labels": ["Counter-Strike", "Counter-Strike: Source", "Shooter", "Shooter", "Microsoft Game Studios", "Vivendi Games"], "name": "", "parents": ["Microsoft Game Studios/Shooter", "Vivendi Games/Shooter", "Microsoft Game Studios", "Vivendi Games", "", ""], "type": "sunburst", "values": [1.11, 0.09, 1.11, 0.09, 1.11, 0.09]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333 ...

# %%
HalfLife = games[games["Name"].str.match("Half-Life") == True]
HalfLife
# Out:
#       Rank         Name Platform    Year    Genre        Publisher  NA_Sales  \
# 281    282    Half-Life       PC  1997.0  Shooter    Vivendi Games      4.03
# 665    667  Half-Life 2       PC  2004.0  Shooter    Vivendi Games      2.28
# 3308  3310  Half-Life 2       XB  2005.0  Shooter  Electronic Arts      0.37
# 3358  3360    Half-Life      PS2  2001.0  Shooter    Vivendi Games      0.29
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 281       0.00      0.09         0.00          4.12
# 665       0.02      0.08         0.00          2.37
# 3308      0.21      0.00         0.03          0.61
# 3358      0.23      0.00         0.08          0.60

# %%
fig = px.sunburst(HalfLife, path = ["Publisher", "Genre", "Name"], values = HalfLife["Global_Sales"],
                      title="Half-Life Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="1a86daa7-e587-46cb-ac7f-34965731d521" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a86daa7-e587-46cb-ac7f-34965731d521")) {                    Plotly.newPlot(                        "1a86daa7-e587-46cb-ac7f-34965731d521",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Vivendi Games/Shooter/Half-Life", "Electronic Arts/Shooter/Half-Life 2", "Vivendi Games/Shooter/Half-Life 2", "Electronic Arts/Shooter", "Vivendi Games/Shooter", "Electronic Arts", "Vivendi Games"], "labels": ["Half-Life", "Half-Life 2", "Half-Life 2", "Shooter", "Shooter", "Electronic Arts", "Vivendi Games"], "name": "", "parents": ["Vivendi Games/Shooter", "Electronic Arts/Shooter", "Vivendi Games/Shooter", "Electronic Arts", "Vivendi Games", "", ""], "type": "sunburst", "values": [4.72, 0.61, 2.37, 0.61, 7.09, 0.61, 7.09]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [ ...

# %%
Fallout = games[games["Name"].str.match("Fallout") == True]
Fallout
# Out:
#         Rank                                               Name Platform  \
# 109      110                                          Fallout 4      PS4
# 208      209                                          Fallout 3     X360
# 287      288                                          Fallout 4     XOne
# 289      290                                 Fallout: New Vegas     X360
# 299      300                                          Fallout 3      PS3
# 430      431                                 Fallout: New Vegas      PS3
# 1630    1632                                          Fallout 4       PC
# 1741    1743                                 Fallout: New Vegas       PC
# 2103    2105                                          Fallout 3       PC
# 6924    6926  Fallout 3 Game Add-On Pack: Broken Steel and P...     X360
# 10565  10567  Fallout 3 Game Add-On Pack: The Pitt and Opera...     X360
# 12213  12215                      Fallout: Brotherhood of Steel      PS2
# 12989  12991                      Fallout: Brotherhood of Steel       XB
# 15229  15232                                    Fallout Trilogy       PC
# 16363  16366                                  Fallout Anthology       PC
#
#          Year         Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 109    2015.0  Role-Playing  Bethesda Softworks      2.47      3.15      0.24
# 208    2008.0  Role-Playing  Bethesda Softworks      3.39      1.03      0.09
# 287    2015.0  Role-Playing  Bethesda Softworks      2.45      1.26      0.01
# 289    2010.0  Role-Playing  Bethesda Softworks      2.65      1.06      0.04
# 299    2008.0  Role-Playing  Bethesda Softworks      2.15      1.20      0.07
# 430    2010.0  Role-Playing  Bethesda Softworks      1.52      1.08      0.10
# 1630   2015.0  Role-Playing  Bethesda Softworks      0.50      0.63      0.00
# 1741   2010.0  Role-Playing  Bethesda Softworks      0.58      0.45      0.00
# 2103   2008.0  Role-Playing  Bethesda Softworks      0.02      0.88      0.00
# 6924   2009.0  Role-Playing  Bethesda Softworks      0.16      0.06      0.00
# 10565  2009.0  Role-Playing  Bethesda Softworks      0.09      0.01      0.00
# 12213  2004.0  Role-Playing  Avalon Interactive      0.03      0.03      0.00
# 12989  2004.0  Role-Playing  Avalon Interactive      0.04      0.01      0.00
# 15229  2004.0  Role-Playing             Ubisoft      0.00      0.02      0.00
# 16363  2015.0        Action  Bethesda Softworks      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales
# 109           1.10          6.96
# 208           0.44          4.96
# 287           0.37          4.09
# 289           0.33          4.08
# 299           0.59          4.01
# 430           0.47          3.17
# 1630          0.10          1.23
# 1741          0.14          1.16
# 2103          0.08          0.99
# 6924          0.02          0.24
# 10565         0.01          0.10
# 12213         0.01          0.07
# 12989         0.00          0.05
# 15229         0.00          0.02
# 16363         0.00          0.01

# %%
fig = px.sunburst(Fallout, path = ["Publisher", "Genre", "Name"], values = Fallout["Global_Sales"],
                      title="Fallout Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="7f806603-64fa-431b-9ce1-9bcbcd1b6487" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f806603-64fa-431b-9ce1-9bcbcd1b6487")) {                    Plotly.newPlot(                        "7f806603-64fa-431b-9ce1-9bcbcd1b6487",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Bethesda Softworks/Role-Playing/Fallout 3", "Bethesda Softworks/Role-Playing/Fallout 3 Game Add-On Pack: Broken Steel and Point Lookout", "Bethesda Softworks/Role-Playing/Fallout 3 Game Add-On Pack: The Pitt and Operation: Anchorage", "Bethesda Softworks/Role-Playing/Fallout 4", "Bethesda Softworks/Action/Fallout Anthology", "Ubisoft/Role-Playing/Fallout Trilogy", "Avalon Interactive/Role-Playing/Fallout: Brotherhood of Steel", "Bethesda Softworks/Role-Playing/Fallout: New Vegas", "Bethesda Softworks/Action", "Avalon Interactive/Role-Playing", "Bethesda Softworks/Role-Playing", "Ubisoft/Role-Playing", "Avalon Interactive", "Bethesda Softworks", "Ubisoft"], "labels": ["Fallout 3", "Fallout 3 Game Add-On Pack: Broken Steel and Point Lookout", "Fallout 3 Game Add-On Pack: The Pitt and Operation: Anchorage", "Fallout 4", "Fallout Anthology", "Fallout Trilogy", "Fallout: Brotherhood of Steel", "Fallout: New Vegas", "Action", "Role-Playing", "Role-Playing", "Role-Playing", "Avalon Interactive", "Bethesda Softworks", "Ubisoft"], "name": "", "parents": ["Bethesda Softworks/Role-Playing", "Bethesda Softworks/Role-Playing", "Bethesda Softworks/Role-Playing", "Bethesda Softworks/Role-Playing", "Bethesda Softworks/Action", "Ubisoft/Role-Playing", "Avalon Interactive/Role-Playing", "Bethesda Softworks/Role-Playing", "Bethesda Softworks", "Avalon Interactive", "Bethesda Softworks", "Ubisoft", "", "", ""], "type": "sunburst", "values": [9.959999999999999, 0.24, 0.1, 12.280000000000001, 0.01, 0.02, 0.12000000000000001, 8.41, 0.01, 0.12000000000000001, 30.989999999999995, 0.02, 0.12000000000000001, 30.999999999999996, 0.02]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.
"Konami Digital Entertainment/Action", "Konami Digital Entertainment/Action", "Konami Digital Entertainment/Action", "Konami Digital Entertainment/Action", "Konami Digital Entertainment/Act ...

# %%
SilentHill = games[games["Name"].str.match("Silent Hill") == True]
SilentHill
# Out:
#         Rank                             Name Platform    Year   Genre  \
# 1154    1156                      Silent Hill       PS  1999.0  Action
# 1549    1551                    Silent Hill 2      PS2  2001.0  Action
# 2873    2875                    Silent Hill 3      PS2  2003.0  Action
# 3420    3422  Silent Hill: Shattered Memories      PS2  2010.0  Action
# 3817    3819             Silent Hill: Origins      PSP  2007.0  Action
# 3939    3941          Silent Hill 4: The Room      PS2  2004.0  Action
# 4095    4097  Silent Hill: Shattered Memories      Wii  2009.0  Action
# 4167    4169            Silent Hill: Downpour      PS3  2012.0  Action
# 5392    5394        Silent Hill HD Collection      PS3  2012.0  Action
# 5492    5494            Silent Hill: Downpour     X360  2012.0  Action
# 5810    5812  Silent Hill: Shattered Memories      PSP  2010.0  Action
# 6201    6203   Silent Hill 2: Restless Dreams       XB  2001.0  Action
# 6946    6948    Silent Hill: Book of Memories      PSV  2012.0  Action
# 7746    7748        Silent Hill HD Collection     X360  2012.0  Action
# 8135    8137          Silent Hill 4: The Room       XB  2004.0  Action
# 11964  11966             Silent Hill: Origins      PS2  2008.0  Action
#
#                           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1154   Konami Digital Entertainment      0.71      0.48      0.30
# 1549   Konami Digital Entertainment      0.62      0.49      0.00
# 2873   Konami Digital Entertainment      0.35      0.27      0.00
# 3420   Konami Digital Entertainment      0.13      0.22      0.01
# 3817   Konami Digital Entertainment      0.22      0.16      0.04
# 3939   Konami Digital Entertainment      0.25      0.19      0.00
# 4095   Konami Digital Entertainment      0.23      0.19      0.01
# 4167   Konami Digital Entertainment      0.21      0.16      0.04
# 5392   Konami Digital Entertainment      0.15      0.11      0.03
# 5492   Konami Digital Entertainment      0.22      0.08      0.00
# 5810   Konami Digital Entertainment      0.09      0.13      0.01
# 6201   Konami Digital Entertainment      0.21      0.06      0.00
# 6946   Konami Digital Entertainment      0.13      0.06      0.00
# 7746   Konami Digital Entertainment      0.11      0.06      0.01
# 8135   Konami Digital Entertainment      0.14      0.04      0.00
# 11964  Konami Digital Entertainment      0.03      0.03      0.00
#
#        Other_Sales  Global_Sales
# 1154          0.10          1.60
# 1549          0.16          1.28
# 2873          0.09          0.71
# 3420          0.23          0.59
# 3817          0.10          0.53
# 3939          0.06          0.51
# 4095          0.05          0.48
# 4167          0.06          0.47
# 5392          0.05          0.34
# 5492          0.03          0.33
# 5810          0.08          0.31
# 6201          0.01          0.28
# 6946          0.04          0.24
# 7746          0.02          0.19
# 8135          0.01          0.18
# 11964         0.01          0.07

# %%
fig = px.sunburst(SilentHill, path = ["Publisher", "Genre", "Name"], values = SilentHill["Global_Sales"],
                      title="Silent Hill Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="d6037e20-cdbd-4d47-81dc-f6e8296ad7d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6037e20-cdbd-4d47-81dc-f6e8296ad7d6")) {                    Plotly.newPlot(                        "d6037e20-cdbd-4d47-81dc-f6e8296ad7d6",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["
# 6365   2013.0   Action              Capcom      0.12      0.11      0.02
# 6625   2008.0   Action              Capcom      0.14      0.04      0.06
# 7690   2013.0   Action              Capcom      0.07      0.08      0.03
# 8297   1997.0   Action              Capcom      0.00      0.00      0.16
# 8442   1997.0   Action              Capcom      0.00      0.00      0.17
# 9428   2015.0   Action              Capcom      0.01      0.05      0.06
# 9671   2006.0   Action              Capcom      0.00      0.00      0.12
# 10752  2015.0   Action              Capcom      0.07      0.02      0.00
# 10957  2012.0  Shooter              Capcom      0.00      0.00      0.09
# 11155  2015.0   Action              Capcom      0.04      0.04      0.00
# 11651  2003.0   Action              Capcom      0.06      0.02      0.00
# 11803  2016.0   Action              Capcom      0.05      0.02      0.00
# 12094  2009.0   Action              Capcom      0.01      0.04      0.00
# 12133  2016.0  Shooter              Capcom      0.05      0.00      0.00
# 12588  2003.0   Action              Capcom      0.05      0.01      0.00
# 12674  2003.0   Action              Capcom      0.04      0.01      0.00
# 13499  2012.0  Shooter              Capcom      0.00      0.04      0.00
# 13531  2006.0   Action              Capcom      0.00      0.00      0.04
# 13751  2012.0   Action              Capcom      0.00      0.03      0.00
# 13806  2013.0   Action              Capcom      0.00      0.03      0.00
# 13950  2016.0  Shooter              Capcom      0.03      0.00      0.00
# 14138  2016.0  Shooter              Capcom      0.03      0.00      0.00
# 14480  2007.0   Action             Ubisoft      0.00      0.02      0.00
# 15403  2016.0   Action              Capcom      0.00      0.00      0.02
# 15437  2016.0   Action              Capcom      0.01      0.01      0.00
# 16095  2016.0   Action              Capcom      0.01      0.00      0.00
# 16569  2016.0  Shooter              Capcom      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 151           0.45          5.82
# 196           0.65          5.11
# 201           0.73          5.05
# 325           0.25          3.77
# 332           0.11          3.72
# 350           0.25          3.62
# 371           0.34          3.51
# 438           0.42          3.15
# 678           0.21          2.34
# 712           0.21          2.26
# 857           0.16          1.98
# 1070          0.06          1.69
# 1209          0.14          1.54
# 1321          0.10          1.45
# 1363          0.05          1.42
# 1529          0.04          1.29
# 1706          0.10          1.18
# 1793          0.03          1.14
# 1900          0.09          1.08
# 2362          0.05          0.88
# 2583          0.12          0.80
# 2647          0.06          0.78
# 2865          0.05          0.71
# 3550          0.05          0.57
# 3590          0.01          0.56
# 3711          0.07          0.54
# 4020          0.03          0.49
# 5172          0.05          0.36
# 5309          0.04          0.35
# 5585          0.03          0.32
# 5692          0.02          0.32
# 6274          0.02          0.27
# 6294          0.01          0.27
# 6365          0.02          0.27
# 6625          0.02          0.25
# 7690          0.01          0.20
# 8297          0.01          0.17
# 8442          0.00          0.17
# 9428          0.01          0.13
# 9671          0.00          0.12
# 10752         0.01          0.10
# 10957         0.00          0.09
# 11155         0.01          0.09
# 11651         0.00          0.08
# 11803         0.01          0.07
# 12094         0.01          0.07
# 12133         0.01          0.07
# 12588         0.00          0.06
# 12674         0.00          0.06
# 13499         0.01          0.04
# 13531         0.00          0.04
# 13751         0.01          0.04
# 13806         0.01          0.04
# 13950         0.00          0.04
# 14138         0.01          0.03
# 14480         0.01          0.03
# 15403         0.00          0.02
# 15437         0.00          0.02
# 16095         0.00          0.01
# 16569         0.00          0.01

# %%
fig = px.sunburst(ResidentEvil, path = ["Publisher", "Genre", "Name"], values = ResidentEvil["Global_Sales"],
                      title="Resident Evil Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id
il: Outbreak", "Resident Evil: Revelations", "Resident Evil: Revelations 2", "Resident Evil: Survivor", "Resident Evil: The Darkside Chronicles", "Resident Evil: The Mercenaries 3D", "Resident Evil: The Umbrella Chronicles", "Resident Evil: Umbrella Corps", "Action", "Action", "Action", "Action", "Shooter", "Capcom", "Eidos Interactive", "Ubisoft", "Virgin Interactive"], "name": "", "parents": ["Capcom/Action", "Virgin Interactive/Action", "Capcom/Action", "Eidos Interactive/Action", "Capcom/Action", "Capcom/Action", "Virgin Interactive/Action", "Capcom/Action", "Capcom/Action", "Eidos Interactive/Action", "Capcom/Action", "Ubisoft/Action", "Capcom/Shooter", "Capcom/Action", "Capcom/Action", " ...

# %%
# MMO's
FinalFantasy = games[games["Name"].str.match("Final Fantasy") == True]
FinalFantasy
# Out:
#         Rank                                         Name Platform    Year  \
# 66        67                            Final Fantasy VII       PS  1997.0
# 86        87                              Final Fantasy X      PS2  2001.0
# 87        88                           Final Fantasy VIII       PS  1999.0
# 147      148                            Final Fantasy XII      PS2  2006.0
# 169      170                           Final Fantasy XIII      PS3  2009.0
# ...      ...                                          ...      ...     ...
# 11453  11455                             Final Fantasy VI       PS  1999.0
# 11562  11564  Final Fantasy XI: Vana'diel Collection 2008      PS2  2007.0
# 15268  15271               Final Fantasy XIV: Heavensward      PS3  2015.0
# 15640  15643               Final Fantasy XIV: Heavensward       PC  2015.0
# 15847  15850       Final Fantasy XI: All-In-One Pack 2006     X360  2006.0
#
#               Genre                    Publisher  NA_Sales  EU_Sales  \
# 66     Role-Playing  Sony Computer Entertainment      3.01      2.47
# 86     Role-Playing  Sony Computer Entertainment      2.91      2.07
# 87     Role-Playing                   SquareSoft      2.28      1.72
# 147    Role-Playing                  Square Enix      1.88      0.00
# 169    Role-Playing                  Square Enix      1.74      1.24
# ...             ...                          ...       ...       ...
# 11453  Role-Playing  Sony Computer Entertainment      0.00      0.00
# 11562  Role-Playing                  Square Enix      0.03      0.03
# 15268        Action                  Square Enix      0.01      0.00
# 15640        Action                  Square Enix      0.01      0.01
# 15847  Role-Playing                  Square Enix      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 66         3.28         0.96          9.72
# 86         2.73         0.33          8.05
# 87         3.63         0.23          7.86
# 147        2.33         1.74          5.95
# 169        1.87         0.52          5.36
# ...         ...          ...           ...
# 11453      0.08         0.01          0.08
# 11562      0.01         0.01          0.08
# 15268      0.01         0.00          0.02
# 15640      0.00         0.00          0.02
# 15847      0.02         0.00          0.02
#
# [77 rows x 11 columns]

# %%
fig = px.sunburst(FinalFantasy, path = ["Publisher", "Genre", "Name"], values = FinalFantasy["Global_Sales"],
                      title="Final Fantasy Series Sales Chart")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="d3c0b48f-577a-4b77-89b7-3504ffdb28b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3c0b48f-577a-4b77-89b7-3504ffdb28b9")) {                    Plotly.newPlot(                        "d3c0b48f-577a-4b77-89b7-3504ffdb28b9",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": 
# %%
WorldOfWarcraft = games[games["Name"].str.match("World of Warcraft") == True]
WorldOfWarcraft
# Out:
#       Rank                                       Name Platform    Year  \
# 137    138                          World of Warcraft       PC  2004.0
# 288    289     World of Warcraft: The Burning Crusade       PC  2007.0
# 799    801               World of Warcraft: Cataclysm       PC  2010.0
# 945    947       World of Warcraft: Mists of Pandaria       PC  2012.0
# 1486  1488  World of Warcraft: Wrath of the Lich King       PC  2008.0
# 4107  4109     World of Warcraft: Warlords of Draenor       PC  2014.0
# 6087  6089                  World of Warcraft: Legion       PC  2016.0
#
#              Genre            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 137   Role-Playing           Activision      0.07      6.21       0.0
# 288   Role-Playing           Activision      2.57      1.52       0.0
# 799   Role-Playing           Activision      1.77      0.32       0.0
# 945   Role-Playing           Activision      0.84      0.76       0.0
# 1486  Role-Playing           Activision      0.01      0.13       0.0
# 4107        Action  Activision Blizzard      0.08      0.36       0.0
# 6087  Role-Playing           Activision      0.14      0.12       0.0
#
#       Other_Sales  Global_Sales
# 137          0.00          6.28
# 288          0.00          4.09
# 799          0.00          2.08
# 945          0.23          1.83
# 1486         1.18          1.32
# 4107         0.04          0.48
# 6087         0.02          0.29

# %%
fig = px.sunburst(WorldOfWarcraft, path = ["Publisher", "Genre", "Name"], values = WorldOfWarcraft["Global_Sales"],
                      title="World of Warcraft")
fig.update_layout(
grid=dict(columns=2, rows=2),
margin=dict(t=40, l=2, r=2, b=5))
fig.show()
# Out:
# <div>                            <div id="8af2754f-8911-4b8a-a80f-a99c17df5642" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8af2754f-8911-4b8a-a80f-a99c17df5642")) {                    Plotly.newPlot(                        "8af2754f-8911-4b8a-a80f-a99c17df5642",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Global_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["Activision/Role-Playing/World of Warcraft", "Activision/Role-Playing/World of Warcraft: Cataclysm", "Activision/Role-Playing/World of Warcraft: Legion", "Activision/Role-Playing/World of Warcraft: Mists of Pandaria", "Activision/Role-Playing/World of Warcraft: The Burning Crusade", "Activision Blizzard/Action/World of Warcraft: Warlords of Draenor", "Activision/Role-Playing/World of Warcraft: Wrath of the Lich King", "Activision Blizzard/Action", "Activision/Role-Playing", "Activision", "Activision Blizzard"], "labels": ["World of Warcraft", "World of Warcraft: Cataclysm", "World of Warcraft: Legion", "World of Warcraft: Mists of Pandaria", "World of Warcraft: The Burning Crusade", "World of Warcraft: Warlords of Draenor", "World of Warcraft: Wrath of the Lich King", "Action", "Role-Playing", "Activision", "Activision Blizzard"], "name": "", "parents": ["Activision/Role-Playing", "Activision/Role-Playing", "Activision/Role-Playing", "Activision/Role-Playing", "Activision/Role-Playing", "Activision Blizzard/Action", "Activision/Role-Playing", "Activision Blizzard", "Activision", "", ""], "type": "sunburst", "values": [6.28, 2.08, 0.29, 1.83, 4.09, 0.48, 1.32, 0.48, 15.89, 15.89, 0.48]}],                        {"grid": {"columns": 2, "rows": 2}, "legend": {"tracegroupgap": 0}, "margin": {"b": 5, "l": 2, "r": 2, "t": 40}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}] ...
